# %% [markdown]
# <a href="https://colab.research.google.com/github/gcochlar/Bootcamp_DataScience/blob/main/Modulo_05/Bootcamp_Mod5_Aula06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src='https://drive.google.com/uc?id=16O9eMrtSeRDnDpZgmneXj34eIClCntvg'>

# %% [markdown]
# # ***Machine Learning:*** **Modelos, Métricas e Validação**
#
# ---
#
# Esse notebook servirá para o acompanhamento das aulas do Módulo 05 do ***Bootcamp de Data Science Aplicada*** realizado pela Alura.
#
# Este módulo dá continuidade ao trabalho iniciado no Módulo 04, de desenvolvimento de um projeto prático que passa por todo o *workflow* em *Data Science*, do entendimento do problema, tratamento e análise dos dados até a proposta de solução utilizando ***Machine Learning***.
#
# Vamos continuar trabalhando com dados da **COVID-19** do **Hospital Sírio Libanês**, sendo que o foco deste módulo será no aprofundamento dos modelos de ***Machine Learning***, bem como suas métricas e procedimentos de validação de resultados.
#
# ---
#
# >No último módulo aplicamos todo nosso conhecimento para analisar dados da COVID-19, entender alguns dos desafios dos hospitais em época de pandemia e propor soluções a partir das análises de dados.
# >
# >Nossa proposta de solução foi utilizar modelos de Machine Learning, mas para tornar isso possível precisamos aprofundar nossos conhecimentos nesta área, testando modelos mais avançados, utilizando métricas adequadas ao problema e validando de forma correta. Neste módulo vamos trabalhar todas estas frentes para tornar nossa solução uma proposta viável.

# %% [markdown]
# ## **Aula 01 -** ***Workflow*** **de** ***Machine Learning***
# ---

# %% [markdown]
# Thiago começou a aula falando do ciclo, do *workflow* de **Machine Learning**.
#
# * Definir o objetivo do estudo e o impacto no negócio
# * Fazer a aquisição e a transformação dos dados (*datawarehouse*, *data lake*)
# * Desenvolvimento do modelo (análise exploratória, treino e teste do modelo)
# * Comunicação dos Resultados (melhor modelo encontrado pode não ser suficiente, o impacto econômico ou no negócio pode ser inadequado, a performance pode ser insuficiente, ...)
# * Fazer o *deploy* e começar monitoramento (fase onde fica disponível para o usuário)

# %% [markdown]
# Na sequência, retomamos o uso do **Colab** como ferramenta, o que eu já vinha fazendo.
#
# Vamos retomar parcialmente o código do módulo passado, em que importamos os dados e fizemos a limpeza inicial, para poder passar a trabalhar em cima dos modelos que queremos treinar.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.dummy import DummyClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree

from sklearn.tree import export_graphviz
from sklearn.tree import export_text
import graphviz

from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, plot_roc_curve

# %%
url = 'https://github.com/gcochlar/Bootcamp_DataScience/blob/main/dados/Kaggle_Sirio_Libanes_ICU_Prediction.xlsx?raw=true'

# %%
dados = pd.read_excel(url)
dados.head()
# Out:
#    PATIENT_VISIT_IDENTIFIER  AGE_ABOVE65  ...    WINDOW  ICU
# 0                         0            1  ...       0-2    0
# 1                         0            1  ...       2-4    0
# 2                         0            1  ...       4-6    0
# 3                         0            1  ...      6-12    0
# 4                         0            1  ...  ABOVE_12    1
#
# [5 rows x 231 columns]

# %% [markdown]
# Vamos seguir a estratégia adotada no módulo passado, de preencher as lacunas de dados usando os métodos de **```backfill```** e **```forward fill```**.
#
# Precisamos também eliminar os dados dos pacientes que entraram no hospital e já foram para a UTI na primeira janela de medições (0-2h), pois as medições podem ter sido realizadas quando ele já estava na UTI, tornando o resultado sem importância para efeitos preditivos.

# %%
def preenche_tabela(dados):
    features_continuas_colunas = dados.iloc[:, 13:-2].columns
    features_continuas = dados.groupby('PATIENT_VISIT_IDENTIFIER', as_index=False)[features_continuas_colunas].fillna(method='bfill').fillna(method='ffill')
    features_categoricas = dados.iloc[:, :13]
    saida = dados.iloc[:, -2:]
    dados_finais = pd.concat([features_categoricas, features_continuas, saida], ignore_index=True,axis=1)
    dados_finais.columns = dados.columns
    return dados_finais

# %%
dados_limpos = preenche_tabela(dados)
a_remover = dados_limpos.query('WINDOW=="0-2" and ICU==1')['PATIENT_VISIT_IDENTIFIER'].values
dados_limpos = dados_limpos.query('PATIENT_VISIT_IDENTIFIER not in @a_remover')
dados_limpos = dados_limpos.dropna()
dados_limpos.describe()
# Out:
#        PATIENT_VISIT_IDENTIFIER  ...          ICU
# count               1760.000000  ...  1760.000000
# mean                 192.818182  ...     0.201705
# std                  110.637724  ...     0.401387
# min                    0.000000  ...     0.000000
# 25%                   97.750000  ...     0.000000
# 50%                  191.500000  ...     0.000000
# 75%                  289.250000  ...     0.000000
# max                  384.000000  ...     1.000000
#
# [8 rows x 229 columns]

# %% [markdown]
# Além disso, vamos ficar com apenas uma linha de dados por paciente. Para isso vamos trazer a informação de necessidade de transferência para a UTI para a primeira janela de observação e desprezar as informações das demais.

# %%
def prepare_window(rows):
    if(np.any(rows['ICU'])):
        rows.loc[rows['WINDOW']=='0-2', 'ICU'] = 1
    return rows.loc[rows['WINDOW'] == '0-2']

dados_limpos = dados_limpos.groupby("PATIENT_VISIT_IDENTIFIER").apply(prepare_window)

dados_limpos.head()
# Out:
#                              PATIENT_VISIT_IDENTIFIER  AGE_ABOVE65  ... WINDOW  ICU
# PATIENT_VISIT_IDENTIFIER                                            ...
# 0                        0                          0            1  ...    0-2    1
# 2                        10                         2            0  ...    0-2    1
# 3                        15                         3            0  ...    0-2    0
# 4                        20                         4            0  ...    0-2    0
# 5                        25                         5            0  ...    0-2    0
#
# [5 rows x 231 columns]

# %%
x_columns = dados.describe().columns
for coluna in dados.columns:
    if coluna not in x_columns:
        print(coluna)
# Out:
# AGE_PERCENTIL
# WINDOW

# %% [markdown]
# O método que usamos no módulo passado para selecionar as colunas de dados que irão alimentar nosso modelo levou a desprezar a coluna **```AGE_PERCENTIL```**, por estar no formato *string*.
#
# Vamos converter os dados para categóricos, de forma que nosso modelo possa considerar essas informações também.

# %%
dados_limpos.AGE_PERCENTIL = dados_limpos.AGE_PERCENTIL.astype("category").cat.codes
dados_limpos.head()
# Out:
#                              PATIENT_VISIT_IDENTIFIER  AGE_ABOVE65  ...  WINDOW  ICU
# PATIENT_VISIT_IDENTIFIER                                            ...
# 0                        0                          0            1  ...     0-2    1
# 2                        10                         2            0  ...     0-2    1
# 3                        15                         3            0  ...     0-2    0
# 4                        20                         4            0  ...     0-2    0
# 5                        25                         5            0  ...     0-2    0
#
# [5 rows x 231 columns]

# %%
np.random.seed(73246)

x_columns = dados.columns
y = dados_limpos['ICU']
x = dados_limpos[x_columns].drop(['ICU','WINDOW'], axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, stratify=y)
modelo_dummy = DummyClassifier()
#modelo_dummy = DummyClassifier(strategy='prior')
modelo_dummy.fit(x_train, y_train)

y_prediction = modelo_dummy.predict(x_test)
accuracy_score(y_test, y_prediction)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/dummy.py:132: FutureWarning: The default value of strategy will change from stratified to prior in 0.24.
#   "stratified to prior in 0.24.", FutureWarning)
# 0.48863636363636365

# %%
modelo = LogisticRegression(max_iter=10000)
modelo.fit(x_train, y_train)

y_prediction = modelo.predict(x_test)
accuracy_score(y_test, y_prediction)
# Out:
# 0.6818181818181818

# %% [markdown]
# Essa primeira aula, além da discussão teórica a respeito do *workflow*, serviu mais para organizar nosso *dataset* para o uso ao longo do módulo.

# %% [markdown]
# #### **Desafio - Transformar a Coluna `AGE_PERCENTIL` em Dados Categóricos, Utilizando Outro Método**
# ---

# %% [markdown]
# Usei a mesma solução que já tinha utilizado no módulo 4, quando fui investigar quais as colunas que não tinham impacto no resultado do modelo.
#
# Em vez de torná-los categóricos, simplesmente converti para numéricos, levando os modelos a ter o mesmo resultado.
#
# Estranhamente, como já havia constatado antes, o uso da coluna **```AGE_PERCENTIL```** reduz a acurácia do modelo de Regressão Logística.

# %%
dados_limpos_desafio = preenche_tabela(dados)
a_remover = dados_limpos_desafio.query('WINDOW=="0-2" and ICU==1')['PATIENT_VISIT_IDENTIFIER'].values
dados_limpos_desafio = dados_limpos_desafio.query('PATIENT_VISIT_IDENTIFIER not in @a_remover')
dados_limpos_desafio = dados_limpos_desafio.dropna()

dados_limpos_desafio = dados_limpos_desafio.groupby("PATIENT_VISIT_IDENTIFIER").apply(prepare_window)

dados_limpos_desafio['AGE_PERCENTIL'] = dados_limpos_desafio['AGE_PERCENTIL'].str.replace('th', '')
dados_limpos_desafio['AGE_PERCENTIL'] = dados_limpos_desafio['AGE_PERCENTIL'].str.replace('Above ', '')
dados_limpos_desafio['AGE_PERCENTIL'] = dados_limpos_desafio['AGE_PERCENTIL'].astype('int8')

np.random.seed(73246)

x_columns = dados_limpos_desafio.columns
y = dados_limpos_desafio['ICU']
x = dados_limpos_desafio[x_columns].drop(['ICU','WINDOW'], axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, stratify=y)
modelo = DummyClassifier()
#modelo = DummyClassifier(strategy='prior')
modelo.fit(x_train, y_train)

y_prediction = modelo.predict(x_test)
accuracy_score(y_test, y_prediction)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/dummy.py:132: FutureWarning: The default value of strategy will change from stratified to prior in 0.24.
#   "stratified to prior in 0.24.", FutureWarning)
# 0.48863636363636365

# %%
modelo = LogisticRegression(max_iter=10000)
modelo.fit(x_train, y_train)

y_prediction = modelo.predict(x_test)
accuracy_score(y_test, y_prediction)
# Out:
# 0.6818181818181818

# %% [markdown]
# Como o Thiago sugeriu usar o próprio **```sklearn```** para fazer essa conversão, verifiquei a documentação de pré-processamento para achar a função **```LabelEncoder```** que faz exatamente isso.
#
# Apliquei abaixo e obtive os mesmos resultados dos modelos.

# %%
dados_limpos_desafio = preenche_tabela(dados)
a_remover = dados_limpos_desafio.query('WINDOW=="0-2" and ICU==1')['PATIENT_VISIT_IDENTIFIER'].values
dados_limpos_desafio = dados_limpos_desafio.query('PATIENT_VISIT_IDENTIFIER not in @a_remover')
dados_limpos_desafio = dados_limpos_desafio.dropna()

dados_limpos_desafio = dados_limpos_desafio.groupby("PATIENT_VISIT_IDENTIFIER").apply(prepare_window)
le = preprocessing.LabelEncoder()
dados_limpos_desafio.AGE_PERCENTIL = le.fit_transform(dados_limpos_desafio.AGE_PERCENTIL)

np.random.seed(73246)

x_columns = dados_limpos_desafio.columns
y = dados_limpos_desafio['ICU']
x = dados_limpos_desafio[x_columns].drop(['ICU','WINDOW'], axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, stratify=y)
modelo = DummyClassifier()
#modelo = DummyClassifier(strategy='prior')
modelo.fit(x_train, y_train)

y_prediction = modelo.predict(x_test)
accuracy_score(y_test, y_prediction)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/dummy.py:132: FutureWarning: The default value of strategy will change from stratified to prior in 0.24.
#   "stratified to prior in 0.24.", FutureWarning)
# 0.48863636363636365

# %%
modelo = LogisticRegression(max_iter=10000)
modelo.fit(x_train, y_train)

y_prediction = modelo.predict(x_test)
accuracy_score(y_test, y_prediction)
# Out:
# 0.6818181818181818

# %% [markdown]
# ### **O que aprendemos nessa aula?**
# ---
#
# >* Qual é um possível **Workflow** em um projeto de **Data Science**;
# >
# >* Realizar uma transformação de dados em dados categóricos;
# >
# >* Aumentar o número de iterações da regressão logística para convergir.
#
# ---

# %% [markdown]
# ## **Aula 02 - Métricas de Avaliação**
# ---

# %% [markdown]
# ### Vídeo 01 - Matriz de Confusão
#
# Antes de entrar na aula propriamente dita foi lançado um novo desafio que está ao final dessa aula.
#
# Na sequência, vamos trabalhar com um novo tipo de modelo, de **Árvore de Decisão**.

# %%
#np.random.seed(73246)

modelo_arvore = DecisionTreeClassifier()
modelo_arvore.fit(x_train, y_train)
predicao_arvore = modelo_arvore.predict(x_test)
accuracy_score(y_test, predicao_arvore)
# Out:
# 0.6590909090909091

# %%
fig, ax = plt.subplots(figsize=(8, 8))
plot_confusion_matrix(modelo_arvore, x_test, y_test, ax=ax)

# %% [markdown]
# Vamos ao entendimento da matriz de confusão que foi plotada.
#
# Ela nos indica no eixo **X** quais foram as previsões do nosso modelo e no eixo **Y** quais eram os reais valores da base de teste.
#
# Sendo assim, tivemos os seguintes resultados:
# * **Verdadeiro Positivo:** 24 pacientes
# * **Verdadeiro Negativo:** 34 pacientes
# * **Falso Positivo:** 13 pacientes
# * **Falso Negativo:** 17 pacientes

# %%
print(classification_report(y_test, predicao_arvore))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.72      0.69        47
#            1       0.65      0.59      0.62        41
#
#     accuracy                           0.66        88
#    macro avg       0.66      0.65      0.65        88
# weighted avg       0.66      0.66      0.66        88

# %% [markdown]
# Vamos ao entendimento das colunas do **```classification_report```**:
# * ***precision:*** utilizado em casos em que o falso positivo é pior que o falso negativo, indica a precisão com que acertamos o resultado. Dos 51 casos que o modelo previu ZERO (34 + 17), tivemos 34 acertos (66,7%). Dos 37 casos que o modelo previu UM (24 + 13), tivemos 24 acertos (64,9%). É indicado para um caso de análise de investimentos, por exemplo.
# * ***recall:*** é indicado para casos em que o falso negativo é muito pior que o falso positivo, como no exemplo de previsão da necessidade de internação em UTI que estamos trabalhando no presente estudo. Dos 47 casos negativos (34 + 13) o modelo acertou 34 (72,3%). Dos 41 casos positivos (17 + 24) o modelo acertou 24 (58,5%).
# * ***f1-score:*** é uma média harmônica das métricas anteriores. Isso faz com que tenhamos um peso maior caso haja um desbalanço entre as duas métricas. A fórmula para calculá-lo é:
#  * **f1-score = 2 * (precisão * recall) / (precisão + recall)**

# %% [markdown]
# #### **Desafio - Verificar o Impacto da Mudança da Coluna ```AGE_PERCENTIL``` nos Resultados**
# ---
#
# Eui já havia feito essa avaliação no final da aula passada, inclusive achei estranho o fato da eficácia do modelo ter caído depois da alteração.
#
# Outro ponto que foi levantado é a possibilidade de estarmos atribuindo um peso maior a essa variável, pois enquanto a maioria das demais variáveis variam entre -1 e 1, essa categoria vai de 0 até 9. A diferença não é significativa, isso poderia ser um ponto importante se a categoria variasse na casa dos milhares ou valores maiores.
#
# De qualquer forma, pretendo fazer esse desafio alterando os valores da variável para o *range* de -1 a 1 e avaliar o novo resultado.
#
# Como temos 10 possíveis valores, acredito que a maneira mais simples é fazer a alteração via dicionário, atribuindo valores -1 para 0 e 1 para 9. Com isso, os demais números vão variar a cada 0,22.

# %%
dict_age = {0:-1, 1:-0.78, 2:-0.56,
            3:-0.34, 4:-0.12, 5:0.1,
            6:0.32, 7:0.54, 8:0.76, 9:1}

dados_limpos_desafio = preenche_tabela(dados)
a_remover = dados_limpos_desafio.query('WINDOW=="0-2" and ICU==1')['PATIENT_VISIT_IDENTIFIER'].values
dados_limpos_desafio = dados_limpos_desafio.query('PATIENT_VISIT_IDENTIFIER not in @a_remover')
dados_limpos_desafio = dados_limpos_desafio.dropna()

dados_limpos_desafio = dados_limpos_desafio.groupby("PATIENT_VISIT_IDENTIFIER").apply(prepare_window)
le = preprocessing.LabelEncoder()
dados_limpos_desafio.AGE_PERCENTIL = le.fit_transform(dados_limpos_desafio.AGE_PERCENTIL)
dados_limpos_desafio.AGE_PERCENTIL = dados_limpos_desafio.AGE_PERCENTIL.map(dict_age)

# %%
np.random.seed(73246)

x_columns = dados_limpos_desafio.columns
y = dados_limpos_desafio['ICU']
x = dados_limpos_desafio[x_columns].drop(['ICU','WINDOW'], axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, stratify=y)
modelo = DummyClassifier()
#modelo = DummyClassifier(strategy='prior')
modelo.fit(x_train, y_train)

y_prediction = modelo.predict(x_test)
accuracy_score(y_test, y_prediction)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/dummy.py:132: FutureWarning: The default value of strategy will change from stratified to prior in 0.24.
#   "stratified to prior in 0.24.", FutureWarning)
# 0.48863636363636365

# %%
modelo = LogisticRegression(max_iter=10000)
modelo.fit(x_train, y_train)

y_prediction = modelo.predict(x_test)
accuracy_score(y_test, y_prediction)
# Out:
# 0.6818181818181818

# %% [markdown]
# Como pode ser visto, a troca dos dados categóricos da coluna **```AGE_PERCENTIL```** que variavam entre 0 e 9 para o intervalo de -1 a 1 não alterou a acurácia dos modelos.

# %% [markdown]
# #### **Desafio - Pesquisar Sobre o** ***F-Score***
# ---

# %% [markdown]
# O ***F-Score*** é uma medida de acurácia que combina os resultados de ***precision*** e ***recall*** na forma de média harmônica.
#
# Usualmente (e é o caso que pode ser visto no **`classification_report`**), utilizamos o ***F1-Score***, que traz um resultado mais equilibrado entre as duas métricas.
#
# Caso o objetivo seja dar ênfase ao resultado de ***precision*** pode-se usar o ***F0,5-Score***. Se o objetivo é dar ênfase ao resultado de ***recall***, usamos o ***F2-Score***.
#
# A fórmula do ***F-Score*** é:
# $$ F(\beta) = \frac{(1 + \beta^2) * precision * recall}{(\beta^2 * precision) + recall} $$
#
# A maneira mais fácil de identificar essa relação é com exemplos. Se temos um modelo que apresenta um resultado de ***precision*** de 0,5 e ***recall*** de 1, teremos os seguintes ***F-Scores***:
# * **F1-Score** = 0,667 ==> média harmônica das métricas
# * **F2-Score** = 0,833 ==> ênfase em ***recall***
# * **F0,5-Score** = 0,555 ==> ênfase em ***precision***
#
# Fontes:
# * [Wikipedia](https://en.wikipedia.org/wiki/F-score)
# * [Towards Data Science](https://towardsdatascience.com/accuracy-precision-recall-or-f1-331fb37c5cb9)
# * [Machine Learning Mastery](https://machinelearningmastery.com/fbeta-measure-for-machine-learning/)
# * [DeepAI](https://deepai.org/machine-learning-glossary-and-terms/f-score)

# %% [markdown]
# #### **Desafio - Pesquisar e Plotar a Árvore de Decisão Criada pelo Modelo**
# ---

# %% [markdown]
# Primeiramente da maneira mais simples (e com uma apresentação mais pobre).

# %%
fig = plt.figure(figsize = (25,20))

plot_tree(modelo_arvore,fontsize= 10)

plt.show()

# %% [markdown]
# Agora vamos passar para uma apresentação mais rica visualmente, onde temos os nomes das variáveis, o percentual de amostras que seguiu por cada galho e cores indicando p resultado predominante nos caminhos seguidos .

# %%
arvore = export_graphviz(modelo_arvore,
                         out_file = None, max_depth = None,
                         feature_names = x.columns,
                         class_names = ['Alta', 'UTI'], label = 'all',
                         filled = True, leaves_parallel = False,
                         impurity = True, node_ids = True,
                         proportion = True, rotate = False,
                         rounded = True, special_characters = True,
                         precision = 3)
plot_arvore = graphviz.Source(arvore, format='png')
plot_arvore

# %%
lista = dados_limpos[x_columns].drop(['ICU','WINDOW'], axis=1).columns.tolist()

arvore_texto = export_text(modelo_arvore, feature_names=lista,
                           max_depth = 10, spacing = 3,
                           decimals = 3, show_weights = True)
print(arvore_texto)
# Out:
# |--- AGE_PERCENTIL <= 6.500
# |   |--- PCR_MEDIAN <= -0.567
# |   |   |--- CREATININ_MIN <= -0.858
# |   |   |   |--- RESPIRATORY_RATE_MEAN <= -0.288
# |   |   |   |   |--- RESPIRATORY_RATE_MEDIAN <= -0.862
# |   |   |   |   |   |--- weights: [0.000, 4.000] class: 1
# |   |   |   |   |--- RESPIRATORY_RATE_MEDIAN >  -0.862
# |   |   |   |   |   |--- GLUCOSE_MAX <= -0.816
# |   |   |   |   |   |   |--- TTPA_MEDIAN <= -0.774
# |   |   |   |   |   |   |   |--- BLOODPRESSURE_DIASTOLIC_DIFF_REL <= -0.724
# |   |   |   |   |   |   |   |   |--- BLAST_MEDIAN <= -0.870
# |   |   |   |   |   |   |   |   |   |--- PCR_MAX <= -0.997
# |   |   |   |   |   |   |   |   |   |   |--- TEMPERATURE_MIN <= 0.462
# |   |   |   |   |   |   |   |   |   |   |   |--- weights: [5.000, 0.000] class: 0
# |   |   |   |   |   |   |   |   |   |   |--- TEMPERATURE_MIN >  0.462
# |   |   |   |   |   |   |   |   |   |   |   |--- weights: [0.000, 2.000] class: 1
# |   |   |   |   |   |   |   |   |   |--- PCR_MAX >  -0.997
# |   |   |   |   |   |   |   |   |   |   |--- DIMER_MEAN <= -0.863
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- DIMER_MEAN >  -0.863
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- BLAST_MEDIAN >  -0.870
# |   |   |   |   |   |   |   |   |   |--- weights: [0.000, 1.000] class: 1
# |   |   |   |   |   |   |   |--- BLOODPRESSURE_DIASTOLIC_DIFF_REL >  -0.724
# |   |   |   |   |   |   |   |   |--- PLATELETS_MAX <= -0.534
# |   |   |   |   |   |   |   |   |   |--- weights: [1.000, 0.000] class: 0
# |   |   |   |   |   |   |   |   |--- PLATELETS_MAX >  -0.534
# |   |   |   |   |   |   |   |   |   |--- weights: [0.000, 2.000] class: 1
# |   |   |   |   |   |   |--- TTPA_MEDIAN >  -0.774
# |   |   |   |   |   |   |   |--- TGP_MEDIAN <= -0.993
# |   |   |   |   |   |   |   |   |--- weights: [3.000, 0.000] class: 0
# |   |   |   |   |   |   |   |--- TGP_MEDIAN >  -0.993
# |   |   |   |   |   |   |   |   |--- LEUKOCYTES_MEDIAN <= -0.866
# |   |   |   |   |   |   |   |   |   |--- weights: [1.000, 0.000] class: 0
# |   |   |   |   |   |   |   |   |--- LEUKOCYTES_MEDIAN >  -0.866
# |   |   |   |   |   |   |   |   |   |--- weights: [0.000, 5.000] class: 1
# |   |   |   |   |   |--- GLUCOSE_MAX >  -0.816
# |   |   |   |   |   |   |--- TGP_MAX <= -0.987
# |   |   |   |   |   |   |   |--- TTPA_MEDIAN <= -0.828
# |   |   |   |   |   |   |   |   |--- weights: [0.000, 9.000] class: 1
# |   |   |   |   |   |   |   |--- TTPA_MEDIAN >  -0.828
# |   |   |   |   |   |   |   |   |--- weights: [2.000, 0.000] class: 0
# |   |   |   |   |   |   |--- TGP_MAX >  -0.987
# |   |   |   |   |   |   |   |--- weights: [7.000, 0.000] class: 0
# |   |   |   |--- RESPIRATORY_RATE_MEAN >  -0.288
# |   |   |   |   |--- PCR_MIN <= -0.886
# |   |   |   |   |   |--- weights: [0.000, 7.000] class: 1
# |   |   |   |   |--- PCR_MIN >  -0.886
# |   |   |   |   |   |--- TTPA_MEDIAN <= -0.839
# |   |   |   |   |   |   |--- weights: [5.000, 0.000] class: 0
# |   |   |   |   |   |--- TTPA_MEDIAN >  -0.839
# |   |   |   |   |   |   |--- weights: [0.000, 2.000] class: 1
# |   |   |--- CREATININ_MIN >  -0.858
# |   |   |   |--- TEMPERATURE_DIFF_REL <= -0.927
# |   |   |   |   |--- FFA_MAX <= -0.499
# |   |   |   |   |   |--- weights: [0.000, 14.000] class: 1
# |   |   |   |   |--- FFA_MAX >  -0.499
# |   |   |   |   |   |--- weights: [1.000, 0.000] class: 0
# |   |   |   |--- TEMPERATURE_DIFF_REL >  -0.927
# |   |   |   |   |--- weights: [2.000, 0.000] class: 0
# |   |--- PCR_MEDIAN >  -0.567
# |   |   |--- LINFOCITOS_MEDIAN <= -0.901
# |   |   |   |--- HEMOGLOBIN_MAX <= -0.232
# |   |   |   |   |--- weights: [0.000, 1.000] class: 1
# |   |   |   |--- HEMOGLOBIN_MAX >  -0.232
# |   |   |   |   |--- weights: [2.000, 0.000] class: 0
# |   |   |--- LINFOCITOS_MEDIAN >  -0.901
# |   |   |   |--- weights: [0.000, 17.000] class: 1
# |--- AGE_PERCENTIL >  6.500
# |   |--- BLOODPRESSURE_DIASTOLIC_MEDIAN <= 0.148
# |   |   |--- FFA_MEAN <= -0.866
# |   |   |   |--- weights: [2.000, 0.000] class: 0
# |   |   |--- FFA_MEAN >  -0.866
# |   |   |   |--- UREA_MIN <= -0.720
# |   |   |   |   |--- PATIENT_VISIT_IDENTIFIER <= 41.000
# |   |   |   |   |   |--- weights: [1.000, 0.000] class: 0
# |   |   |   |   |--- PATIENT_VISIT_IDENTIFIER >  41.000
# |   |   |   |   |   |--- GGT_MEDIAN <= -0.988
# |   |   |   |   |   |   |--- FFA_MIN <= -0.695
# |   |   |   |   |   |   |   |--- weights: [1.000, 0.000] class: 0
# |   |   |   |   |   |   |--- FFA_MIN >  -0.695
# |   |   |   |   |   |   |   |--- weights: [0.000, 1.000] class: 1
# |   |   |   |   |   |--- GGT_MEDIAN >  -0.988
# |   |   |   |   |   |   |--- weights: [0.000, 44.000] class: 1
# |   |   |   |--- UREA_MIN >  -0.720
# |   |   |   |   |--- PLATELETS_MIN <= -0.646
# |   |   |   |   |   |--- weights: [0.000, 5.000] class: 1
# |   |   |   |   |--- PLATELETS_MIN >  -0.646
# |   |   |   |   |   |--- BILLIRUBIN_MEDIAN <= -0.968
# |   |   |   |   |   |   |--- weights: [0.000, 1.000] class: 1
# |   |   |   |   |   |--- BILLIRUBIN_MEDIAN >  -0.968
# |   |   |   |   |   |   |--- weights: [4.000, 0.000] class: 0
# |   |--- BLOODPRESSURE_DIASTOLIC_MEDIAN >  0.148
# |   |   |--- RESPIRATORY_RATE_MIN <= -0.321
# |   |   |   |--- NEUTROPHILES_MEAN <= -0.889
# |   |   |   |   |--- weights: [0.000, 1.000] class: 1
# |   |   |   |--- NEUTROPHILES_MEAN >  -0.889
# |   |   |   |   |--- weights: [9.000, 0.000] class: 0
# |   |   |--- RESPIRATORY_RATE_MIN >  -0.321
# |   |   |   |--- TEMPERATURE_DIFF <= -0.964
# |   |   |   |   |--- weights: [0.000, 4.000] class: 1
# |   |   |   |--- TEMPERATURE_DIFF >  -0.964
# |   |   |   |   |--- weights: [1.000, 0.000] class: 0

# %% [markdown]
# ### Vídeo 02 - Curva ROC e AUC
#
# Começamos com reforço de conceitos:
# * ***Precision*** ou Precisão: qual o percentual de realmente positivas dentro do total de classificações positivas feitas pelo modelo (VP / (VP+FP))
# * ***Recall*** ou Revocação: qual o percentual de realmente positivas dentro do total de casos positivos que realmente havia na base (VP / (VP+FN))
#
# Daí evoluímos para novos conceitos, da curva ROC e AUC.
# * **Curva ROC:** é a curva que plota a taxa de verdadeiros positivos (também chamada de *sensibilidade*) no eixo **Y** e a taxa de falsos positivos (ou *especificidade*) na forma de 1 - especificidade no eixo **X**. Com isso, como podemos ver na imagem abaixo, quanto mais próxima do canto superior esquerdo do gráfico, melhor a qualidade do modelo
#
# <img src='https://upload.wikimedia.org/wikipedia/commons/3/3d/Curva_ROC.svg' width='400px' height='300px'>
#
# * **AUC:** é a *Area Under the Curve*, ou seja, a área medida embaixo da curva ROC plotada. É uma forma objetiva de termos uma comparação entre modelos, o que pode ser difícil de avaliar visualmente no gráfico. Na imagem abaixo, é a área marcada em amarelo.
#
# <img src='https://miro.medium.com/max/700/1*2nd7NTEBosPakccmLVWy9A.png' width='400px' height='300px'>
#
# Em ambas imagens podemos ver uma linha pontilhada na diagonal do gráfico. Essa linha representa a performance esperada de um classificador aleatório. Podemos considerar que a performance de qualquer modelo precisa ser pelo menos superior a isso, ou seja, a curva ROC precisa estar acima dessa diagonal.
#
# Fontes:
# * [SANAR](https://www.sanarmed.com/curva-roc-isso-realmente-faz-diferenca-colunistas)
# * [Wikipedia](https://pt.wikipedia.org/wiki/Caracter%C3%ADstica_de_Opera%C3%A7%C3%A3o_do_Receptor)

# %%
#np.random.seed(73246)

prob_arvore = modelo_arvore.predict_proba(x_test)
roc_auc_score(y_test, prob_arvore[:,1])
# Out:
# 0.5812143227815256

# %%
def roda_modelo(modelo, dados):

    x_columns = dados.columns
    y = dados['ICU']
    x = dados[x_columns].drop(['ICU','WINDOW'], axis=1)
    
    x_train, x_test, y_train, y_test = train_test_split(x, y, stratify=y)

    modelo.fit(x_train, y_train)
    predicao = modelo.predict(x_test)
    prob_predic = modelo.predict_proba(x_test)

    auc = roc_auc_score(y_test, prob_predic[:,1])
    print(f'AUC {auc}')
    print('\nClassification Report')
    print(classification_report(y_test, predicao))

# %%
roda_modelo(modelo_arvore, dados_limpos)
# Out:
# AUC 0.6040477426050858
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.61      0.74      0.67        47
#            1       0.61      0.46      0.53        41
#
#     accuracy                           0.61        88
#    macro avg       0.61      0.60      0.60        88
# weighted avg       0.61      0.61      0.61        88

# %%
roda_modelo(modelo, dados_limpos)
# Out:
# AUC 0.7410482615464452
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.64      0.81      0.72        47
#            1       0.69      0.49      0.57        41
#
#     accuracy                           0.66        88
#    macro avg       0.67      0.65      0.64        88
# weighted avg       0.67      0.66      0.65        88

# %% [markdown]
# #### **Desafio - Desenvolver Função que Plote a Curva ROC**
# ---
#
# Desafio Extra - Plotar as Curvas de Diversos Modelos para Comparação

# %%
fig, ax = plt.subplots(figsize = (16,8))
plot_roc_curve(modelo, x_test, y_test, ax=ax)
plot_roc_curve(modelo_arvore, x_test, y_test, ax=ax)
plot_roc_curve(modelo_dummy, x_test, y_test, ax=ax)

# %% [markdown]
# #### **Desafio - Como Reduzir o Efeito da Aleatoriedade no Comparativo Entre Modelos**
# ---
#
# Foi solicitado que se trabalhasse uma maneira criativa de reduzir a aleatoriedade dos resultados, sem buscar a documentação, que deve sugerir a maneira mais tradicional que será vista na aula 03.
#
# Tinha pensado em usar o **`random_state`** ao executar o **`train_test_split`** mas pensando melhor acho que isso apenas resolve a questão de termos resultados diferentes a cada execução. Para um determinado **`random_state`** podemos ter um modelo que desempenha melhor e para outro **`random_state`**, uma resposta diferente.
#
# Entendo que o mais correto seria usar a metodologia de validação cruzada que vimos no módulo anterior, pois daí usaremos várias amostras diferentes de dados para treino e teste e teremos como medida final a média dos resultados obtidos.

# %% [markdown]
# ### **O que aprendemos nessa aula?**
# ---
#
# >* Como usar uma árvore de decisão;
# >
# >* Analisar a qualidade dos resultados com a matriz de confusão;
# >
# >* Gerar um relatório do resultado da classificação;
# >
# >* O que é *Recall*, *Precision*, *F-Score* e *AUC*.
#
# ---

# %% [markdown]
# ## **Aula 03 - Aleatoriedade de Modelos**
# ---

# %% [markdown]
# A ideia dessa aula é tentar reduzir o impacto da aleatoriedade na escolha dos dados que irão treinar e testar os modelos.
#
# A solução indicada foi definir uma nova função que executa *n* vezes o processo de separação dos dados em treino e teste, treina os modelos e depois calcula a média e o desvio padrão das ***AUCs*** encontradas.

# %%
def roda_n_modelos(modelo, dados, n):
    x_columns = dados.columns
    y = dados['ICU']
    x = dados[x_columns].drop(['ICU', 'WINDOW'], axis = 1)

    auc_lista = []

    for _ in range(n):
        x_train, x_test, y_train, y_test = train_test_split(x, y, stratify = y)

        modelo.fit(x_train, y_train)
        prob_predic = modelo.predict_proba(x_test)
        auc = roc_auc_score(y_test, prob_predic[:,1])
        auc_lista.append(auc)

    auc_medio = np.mean(auc_lista)
    auc_std = np.std(auc_lista)
    print(f'Resultados após {n} execuções')
    print(f'AUC Médio {auc_medio}')
    print(f'Intervalo {auc_medio - 2 * auc_std} a {auc_medio + 2 * auc_std}')
    print(f'Range     {2 * auc_std}')

# %%
roda_n_modelos(modelo_arvore, dados_limpos, 100)
# Out:
# Resultados após 100 execuções
# AUC Médio 0.6276440062272963
# Intervalo 0.5385560923038623 a 0.7167319201507304
# Range     0.08908791392343408

# %%
roda_n_modelos(modelo, dados_limpos, 100)
# Out:
# Resultados após 100 execuções
# AUC Médio 0.7580487804878048
# Intervalo 0.6625385155048092 a 0.8535590454708003
# Range     0.09551026498299552

# %% [markdown]
# Com os resultados obtidos podemos ver que o modelo de Regressão Logística apresenta um desempenho melhor que o de Árvore de Decisão, mas me chamou a atenção também a diferença de performance dos modelos.
#
# Para executar 100 vezes o modelo de Árvore de Decisão precisou de aproximadamente 2,5 segundos, enquanto o modelo de Regressão Logística levou mais de 43 segundos. Essa diferença pode ser crítica em bases de dados maiores ou quando for necessário um maior número de execuções.

# %% [markdown]
# #### **Desafio - Estudar a Documentação do `sklearn` e Testar Outros Modelos**
# ---

# %% [markdown]
# Identifiquei na documentação do **```sklearn```** outros dois tipos de modelos que poderíamos aplicar ao nosso problema, o **SVC** (*Support Vector Classification*) e o **Random Forest Classifier**.

# %%
from sklearn.svm import SVC

# %%
mod_svc_linear = SVC(kernel = 'linear', probability = True)

mod_svc_quadrado = SVC(kernel = 'poly', degree = 2, probability = True)

mod_svc_5 = SVC(kernel = 'poly', degree = 5, probability = True)

# %%
roda_n_modelos(mod_svc_linear, dados_limpos, 5)

#roda_n_modelos(mod_svc_linear, dados_limpos, 50)
# Out:
# Resultados após 5 execuções
# AUC Médio 0.7558380902957965
# Intervalo 0.6239358952256842 a 0.8877402853659089
# Range     0.1319021950701123

# %% [markdown]
# **Imagem do Resultado Obtido com 50 Execuções**
#
# ![image.png](data:image/png;base64,...)

# %%
#roda_n_modelos(mod_svc_quadrado, dados_limpos, 5)

roda_n_modelos(mod_svc_quadrado, dados_limpos, 50)
# Out:
# Resultados após 50 execuções
# AUC Médio 0.4321224701608719
# Intervalo 0.07755744290085831 a 0.7866874974208855
# Range     0.3545650272600136

# %%
#roda_n_modelos(mod_svc_5, dados_limpos, 5)

roda_n_modelos(mod_svc_5, dados_limpos, 50)
# Out:
# Resultados após 50 execuções
# AUC Médio 0.4190088220031136
# Intervalo 0.08037757513170929 a 0.757640068874518
# Range     0.33863124687140433

# %% [markdown]
# O modelo **SVC** apresentou um desempenho fraco de maneira geral. Apesar do **SVC Linear** ter chegado a resultados semelhantes ao da Regressão Logística, levou mais de 7 minutos sendo executado. Inclusive reduzi para execução de apenas 5 vezes, para quando for necessário rodar todo o notebook novamente.
#
# As variações (**SVC Quadrático** e **SVC Polinomial Grau 5**) foram de execução mais rápida mas apresentaram resultados inferiores a 50% com alto desvio padrão.

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
mod_RFC = RandomForestClassifier()

# %%
roda_n_modelos(mod_RFC, dados_limpos, 100)
# Out:
# Resultados após 100 execuções
# AUC Médio 0.7861261027503892
# Intervalo 0.7042545924155176 a 0.8679976130852608
# Range     0.08187151033487158

# %% [markdown]
# Considero que o ***Random Forest Classifier*** apresentou um bom desempenho, tanto em termos de tempo de execução quanto em termos de **AUC** encontrado.
#
# Até agora, foi o melhor desempenho obtido.

# %%
mod_svc_linear_b = SVC(kernel = 'linear', probability = True, C = 0.025)

mod_svc_5b = SVC(kernel = 'poly', degree = 3, probability = True, gamma = 2, C = 0.025)

#mod_svc_5b = SVC(kernel = 'poly', degree = 3, probability = True, gamma = 2, C = 1)

# %%
roda_n_modelos(mod_svc_linear_b, dados_limpos, 50)
# Out:
# Resultados após 50 execuções
# AUC Médio 0.7759885832900882
# Intervalo 0.6921398883429932 a 0.8598372782371833
# Range     0.08384869494709503

# %%
#roda_n_modelos(mod_svc_5b, dados_limpos, 2)

# %% [markdown]
# Olhando nos exemplos da documentação do **SVC** eu vi esses parâmetros alterados para os modelos linear (`C`) e polinomial (`C` e `gamma`) e resolvi testar mais essas duas parametrizações.
#
# O modelo linear trouxe praticamente os mesmos resultados de **AUC** em apenas 11 segundos (contra os mais de 7 minutos anteriormente).
#
# Já o modelo polinomial, com esses parâmetros, não rodou. Tentei reduzir para rodar apenas 2 vezes e mesmo assim ele atingia o tempo limite de conexão e me derrubava do **Colab**. Não vou conseguir testar esse modelo.

# %% [markdown]
# ### **O que aprendemos nessa aula?**
# ---
#
# >* Como criar uma função para treinar N vezes seu modelo;
# >
# >* Como a aleatoriedade interfere na sua escolha;
# >
# >* Cálculo do intervalo mínimo e máximo para a métrica **AUC**;
# >
# >* Como reduzir o efeito de aleatoriedade na tomada de decisão.
#
# ---

# %% [markdown]
# ## **Aula 04 - Validação Cruzada**
# ---

# %% [markdown]
# Nessa aula vamos retomar a estratégia da validação cruzada que vimos no módulo 03. Nela nós separamos o nosso *dataset* em diversos pedaços e repetimos o *fit* do modelo diversas vezes, alternando os pedaços que usamos para teste, como podemos ver na figura abaixo.
#
# <img src='https://drive.google.com/uc?id=1mx-L_8WfwNYRKea5hWS8-LWQqfXrP91X' width='500px' height='300px'>
#
# No exemplo, a base de dados é dividida em 5 blocos e, a cada execução, o bloco em cinza é usado para testes, obtendo acurácias diferentes. O resultado do modelo será a média das acurácias obtidas.

# %%
from sklearn.model_selection import cross_validate
from sklearn.model_selection import StratifiedKFold

# %%
cv = StratifiedKFold(n_splits = 5, shuffle = True)

result = cross_validate(modelo, x, y, cv = cv)
result
# Out:
# {'fit_time': array([0.62212276, 0.27823973, 0.54109168, 0.5288229 , 0.5803194 ]),
#  'score_time': array([0.00231338, 0.00221157, 0.00221896, 0.00223184, 0.00221491]),
#  'test_score': array([0.67605634, 0.70422535, 0.71428571, 0.74285714, 0.68571429])}

# %%
cv = StratifiedKFold(n_splits = 5, shuffle = True)

result = cross_validate(modelo_arvore, x, y, cv = cv)
result
# Out:
# {'fit_time': array([0.03261685, 0.03005934, 0.02326393, 0.01771951, 0.01783204]),
#  'score_time': array([0.00241113, 0.00235844, 0.00160956, 0.00160718, 0.00164533]),
#  'test_score': array([0.46478873, 0.61971831, 0.62857143, 0.65714286, 0.58571429])}

# %%
from sklearn.model_selection import RepeatedStratifiedKFold

# %%
cv = RepeatedStratifiedKFold(n_splits = 5, n_repeats = 10)

result = cross_validate(modelo, x, y, cv = cv)
result
# Out:
# {'fit_time': array([0.49953675, 0.48835588, 0.29774833, 0.58094263, 0.60446644,
#         0.51354694, 0.20172119, 0.56275296, 0.53252172, 0.51995492,
#         0.56208467, 0.2344718 , 0.22241831, 0.67891455, 0.47803831,
#         0.46574903, 0.2106688 , 0.1908567 , 0.52565002, 0.48166919,
#         0.51482964, 0.53958607, 0.23237467, 0.43222833, 0.24500513,
#         0.49558377, 0.19484878, 0.52245069, 0.7505641 , 0.548491  ,
#         0.22247648, 0.62935495, 0.58264208, 0.51432538, 0.59420252,
#         0.57695961, 0.20560122, 0.57556772, 0.56655288, 0.56572676,
#         0.48048949, 0.56623006, 0.47512674, 0.61648989, 0.6059289 ,
#         0.16404557, 0.54682446, 0.55431318, 0.56362414, 0.52061296]),
#  'score_time': array([0.00232053, 0.00230813, 0.00239253, 0.00355077, 0.00226617,
#         0.00224948, 0.00223589, 0.00240183, 0.00221658, 0.00235415,
#         0.00220704, 0.00242996, 0.0022471 , 0.00223327, 0.00220394,
#         0.00224185, 0.00218964, 0.0022018 , 0.00247955, 0.00234652,
#         0.00243139, 0.00222325, 0.00224328, 0.00224805, 0.00228977,
#         0.00225568, 0.00237966, 0.0021987 , 0.00356674, 0.00226974,
#         0.0022397 , 0.00223422, 0.0021615 , 0.00222921, 0.00554061,
#         0.00225973, 0.00244975, 0.00224566, 0.00252986, 0.00221062,
#         0.002244  , 0.00223899, 0.00224185, 0.0023365 , 0.00221086,
#         0.00230479, 0.00220776, 0.00223684, 0.00399256, 0.00222468]),
#  'test_score': array([0.67605634, 0.69014085, 0.72857143, 0.74285714, 0.8       ,
#         0.76056338, 0.66197183, 0.72857143, 0.7       , 0.71428571,
#         0.69014085, 0.64788732, 0.78571429, 0.64285714, 0.68571429,
#         0.77464789, 0.74647887, 0.74285714, 0.62857143, 0.62857143,
#         0.69014085, 0.73239437, 0.75714286, 0.72857143, 0.77142857,
#         0.77464789, 0.64788732, 0.68571429, 0.8       , 0.68571429,
#         0.64788732, 0.74647887, 0.78571429, 0.72857143, 0.74285714,
#         0.67605634, 0.76056338, 0.71428571, 0.81428571, 0.65714286,
#         0.70422535, 0.67605634, 0.82857143, 0.7       , 0.65714286,
#         0.73239437, 0.64788732, 0.72857143, 0.7       , 0.71428571])}

# %%
result['test_score'].std()
# Out:
# 0.05032465782958986

# %%
def roda_modelo_cv(modelo, dados, n_splits, n_repeats):

    np.random.seed(1231234)

    dados = dados.sample(frac = 1).reset_index(drop = True)
    x_columns = dados.columns
    y = dados['ICU']
    x = dados[x_columns].drop(['ICU','WINDOW'], axis=1)
    
    cv = RepeatedStratifiedKFold(n_splits = n_splits, n_repeats = n_repeats)
    result = cross_validate(modelo, x, y, cv = cv, scoring = 'roc_auc')

    auc_medio = result['test_score'].mean()
    auc_std = result['test_score'].std()

    print(f'AUC Médio {auc_medio}')
    print(f'Intervalo {auc_medio - 2 * auc_std} a {auc_medio + 2 * auc_std}')
    print(f'Range     {2 * auc_std}')

# %%
roda_modelo_cv(modelo, dados_limpos, 5, 10)
# Out:
# AUC Médio 0.7575511875511876
# Intervalo 0.6366273412799195 a 0.8784750338224556
# Range     0.12092384627126805

# %%
roda_modelo_cv(modelo_arvore, dados_limpos, 5, 10)
# Out:
# AUC Médio 0.6279279683391525
# Intervalo 0.4988394445682657 a 0.7570164921100394
# Range     0.12908852377088686

# %%
roda_modelo_cv(mod_RFC, dados_limpos, 5, 10)
# Out:
# AUC Médio 0.7939557739557739
# Intervalo 0.7055497813730257 a 0.882361766538522
# Range     0.08840599258274821

# %% [markdown]
# #### **Desafio - Testar Outras `splitter_classes` e Observar as Diferenças**
# ---

# %% [markdown]
# ##### ***StratifiedShuffleSplit***
# ---

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# %%
cv = StratifiedShuffleSplit(n_splits = 5)

result = cross_validate(modelo, x, y, cv = cv, scoring = 'roc_auc')
auc_medio = result['test_score'].mean()
auc_std = result['test_score'].std()

print(f'AUC Médio {auc_medio}')
print(f'Intervalo {auc_medio - 2 * auc_std} a {auc_medio + 2 * auc_std}')
print(f'Range     {2 * auc_std}')
# Out:
# AUC Médio 0.834674922600619
# Intervalo 0.7143151275312165 a 0.9550347176700216
# Range     0.12035979506940256

# %%
cv = StratifiedShuffleSplit(n_splits = 5)

result = cross_validate(modelo_arvore, x, y, cv = cv, scoring = 'roc_auc')
auc_medio = result['test_score'].mean()
auc_std = result['test_score'].std()

print(f'AUC Médio {auc_medio}')
print(f'Intervalo {auc_medio - 2 * auc_std} a {auc_medio + 2 * auc_std}')
print(f'Range     {2 * auc_std}')
# Out:
# AUC Médio 0.609907120743034
# Intervalo 0.44510349975087904 a 0.774710741735189
# Range     0.16480362099215498

# %% [markdown]
# ### **O que aprendemos nessa aula?**
# ---
#
# >* O que é Validação Cruzada;
# >
# >* Como usar a Validação Cruzada do **`Sci-Kit Learn`**;
# >
# >* Qual Validação Cruzada usar no nosso caso de estudo.
#
# ---

# %% [markdown]
# ## **Aula 05 - Desafios em** ***Machine Learning***
# ---

# %% [markdown]
# Um dos pontos a ser analisado nessa aula é o *overfitting*, em que o modelo fica muito bem adaptado aos dados de treino mas não consegue fazer um bom trabalho de previsão para dados novos.
#
# Vamos alterar alguns parâmetros do nosso modelo de Árvore de Decisão, consultando a documentação.
# [***Decision Tree***](https://scikit-learn.org/stable/modules/tree.html)
#
# Um dos primeiros parâmetros que pode ser alterado é o **`max_depth`**, que determina a profundidade máxima que nossa árvore vai atingir.

# %%
modelo_arvore_d3 = DecisionTreeClassifier(max_depth=3)
modelo_arvore_d4 = DecisionTreeClassifier(max_depth=4)
modelo_arvore_d5 = DecisionTreeClassifier(max_depth=5)
modelo_arvore_d6 = DecisionTreeClassifier(max_depth=6)

# %%
print('\nModelo Árvore - Depth = 3')
roda_modelo_cv(modelo_arvore_d3, dados_limpos, 5, 10)
print('\nModelo Árvore - Depth = 4')
roda_modelo_cv(modelo_arvore_d4, dados_limpos, 5, 10)
print('\nModelo Árvore - Depth = 5')
roda_modelo_cv(modelo_arvore_d5, dados_limpos, 5, 10)
print('\nModelo Árvore - Depth = 6')
roda_modelo_cv(modelo_arvore_d6, dados_limpos, 5, 10)
# Out:
# Modelo Árvore - Depth = 3
# AUC Médio 0.6643847795163584
# Intervalo 0.5408496038380549 a 0.787919955194662
# Range     0.1235351756783035
#
# Modelo Árvore - Depth = 4
# AUC Médio 0.6554932930837536
# Intervalo 0.5297661979528577 a 0.7812203882146495
# Range     0.1257270951308959
#
# Modelo Árvore - Depth = 5
# AUC Médio 0.6475058192163456
# Intervalo 0.5011322213480258 a 0.7938794170846655
# Range     0.14637359786831977
#
# Modelo Árvore - Depth = 6
# AUC Médio 0.6239047951959137
# Intervalo 0.46637314891829074 a 0.7814364414735366
# Range     0.15753164627762292

# %% [markdown]
# Podemos ver que, após uma melhora inicial em relação ao modelo em que não havíamos passado o parâmetro, a partir de **`max_depth = 5`** a acurácia volta a cair...
#
# Vamos alterar nossa função **`roda_modelo_cv`** para nos fornecer também o **AUC** dos dados de treinamento, para entender melhor o comportamento dos modelos.

# %%
def roda_modelo_cv_v2(modelo, dados, n_splits, n_repeats):

    np.random.seed(1231234)

    dados = dados.sample(frac = 1).reset_index(drop = True)
    x_columns = dados.columns
    y = dados['ICU']
    x = dados[x_columns].drop(['ICU','WINDOW'], axis=1)
    
    cv = RepeatedStratifiedKFold(n_splits = n_splits, n_repeats = n_repeats)
    result = cross_validate(modelo, x, y, cv = cv, scoring = 'roc_auc', return_train_score = True)

    auc_medio = result['test_score'].mean()
    auc_medio_treino = result['train_score'].mean()
    auc_std = result['test_score'].std()
    auc_std_treino = result['train_score'].std()

    print(f'==AUC Médio {auc_medio}')
    print(f'==Intervalo {auc_medio - 2 * auc_std} a {auc_medio + 2 * auc_std}')
    print(f'==Range     {2 * auc_std}')
    print(f'\n===AUC Médio de Treino {auc_medio_treino}')
    print(f'===Intervalo {auc_medio_treino - 2 * auc_std_treino} a {auc_medio_treino + 2 * auc_std_treino}')
    print(f'===Range     {2 * auc_std_treino}')

# %%
print('\nModelo Árvore - Depth = 3')
roda_modelo_cv_v2(modelo_arvore_d3, dados_limpos, 5, 10)
print('\nModelo Árvore - Depth = 4')
roda_modelo_cv_v2(modelo_arvore_d4, dados_limpos, 5, 10)
print('\nModelo Árvore - Depth = 5')
roda_modelo_cv_v2(modelo_arvore_d5, dados_limpos, 5, 10)
print('\nModelo Árvore - Depth = 6')
roda_modelo_cv_v2(modelo_arvore_d6, dados_limpos, 5, 10)
# Out:
# Modelo Árvore - Depth = 3
# ==AUC Médio 0.6643847795163584
# ==Intervalo 0.5408496038380549 a 0.787919955194662
# ==Range     0.1235351756783035
#
# ===AUC Médio de Treino 0.8243714304989842
# ===Intervalo 0.7927219045021597 a 0.8560209564958087
# ===Range     0.031649525996824475
#
# Modelo Árvore - Depth = 4
# ==AUC Médio 0.6554932930837536
# ==Intervalo 0.5297661979528577 a 0.7812203882146495
# ==Range     0.1257270951308959
#
# ===AUC Médio de Treino 0.8832038893699776
# ===Intervalo 0.8487939503147206 a 0.9176138284252346
# ===Range     0.03440993905525705
#
# Modelo Árvore - Depth = 5
# ==AUC Médio 0.6475058192163456
# ==Intervalo 0.5011322213480258 a 0.7938794170846655
# ==Range     0.14637359786831977
#
# ===AUC Médio de Treino 0.9275331115338461
# ===Intervalo 0.8963003095675415 a 0.9587659135001507
# ===Range     0.031232801966304676
#
# Modelo Árvore - Depth = 6
# ==AUC Médio 0.6239047951959137
# ==Intervalo 0.46637314891829074 a 0.7814364414735366
# ==Range     0.15753164627762292
#
# ===AUC Médio de Treino 0.9567921210944048
# ===Intervalo 0.9299022025208 a 0.9836820396680096
# ===Range     0.02688991857360474

# %% [markdown]
# Podemos ver que o **AUC** de nossos dados de treino vão aumentando cada vez mais, enquanto o **AUC** geral do modelo começa a cair.
#
# Isso é um indicativo de ***overfitting***, ou seja, nosso modelo está ficando extremamente aderente aos dados de treino, mas com isso reduz a possibilidade de fazer previsões para os dados de teste e dados futuros.
#
# Vamos fazer uma iteração para rodar o modelo com várias profundidades e plotar os resultados de **AUC**.

# %%
def roda_modelo_cv_v3(modelo, dados, n_splits, n_repeats):

    np.random.seed(1231234)

    dados = dados.sample(frac = 1).reset_index(drop = True)
    x_columns = dados.columns
    y = dados['ICU']
    x = dados[x_columns].drop(['ICU','WINDOW'], axis=1)
    
    cv = RepeatedStratifiedKFold(n_splits = n_splits, n_repeats = n_repeats)
    result = cross_validate(modelo, x, y, cv = cv, scoring = 'roc_auc', return_train_score = True)

    auc_medio = result['test_score'].mean()
    auc_medio_treino = result['train_score'].mean()

    return auc_medio, auc_medio_treino

# %%
teste_lista = []
treino_lista = []

for i in range(1,15):
    modelo_arvore_i = DecisionTreeClassifier(max_depth=i)
    teste, treino = roda_modelo_cv_v3(modelo_arvore_i, dados_limpos, 5, 10)
    teste_lista.append(teste)
    treino_lista.append(treino)

# %%
x = range(1,15)
plt.plot(x, teste_lista, color = 'darkblue', lw = 2)
plt.plot(x, treino_lista, color = 'orange', lw = 2)

# %% [markdown]
# Podemos ver que a linha laranja, que representa o **AUC** dos nossos dadso de treino se aproxima rapidamente dos 100%. Enquanto isso, a performance do modelo com os dados de teste cai. Isso não ocorre na mesma proporção, mas mostra a piora do modelo de predição.
#
# Nesse caso, temos ***overfitting***.

# %% [markdown]
# #### **Desafio - Deixar o Gráfico Bonitão**
# ---

# %%
import matplotlib.ticker as ticker

fig, ax = plt.subplots(figsize=(12,6))

plt.suptitle('Comparação AUC Médio Previsão x Treino - Decision Tree', fontsize = 25, fontweight='bold')
plt.plot(x, teste_lista, color = 'darkblue', lw = 2, label='Dados de Teste')
plt.plot(x, treino_lista, color = 'orange', lw = 2, label='Dados de Treino')

plt.xlabel('Nº de Iterações',
             fontsize=15, fontweight = 'bold')
plt.ylabel('AUC Médio',
             fontsize=15, fontweight = 'bold')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.00%}'))
plt.legend(fontsize = 15, loc='upper right',bbox_to_anchor=(1.3, 1))
plt.ylim(0,1.1)
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
plt.show()

# %% [markdown]
# #### **Desafio - Criar Forçadamente um *Overfit* com Outra Base de Dados e Outro Modelo de *Machine Learning*, Plotar Gráficos e Analisar**
# ---
#
# Sugestão: Base de Dados Titanic do ***Kaggle***

# %% [markdown]
# #### **Desafio - Estudar Mais Sobre *Overfit* e *Underfit***
# ---

# %% [markdown]
# Li alguns artigos a respeito, seguem os *links* abaixo.
#
# [IBM.com](https://www.ibm.com/cloud/learn/underfitting)
#
# [Geeks For Geeks](https://www.geeksforgeeks.org/underfitting-and-overfitting-in-machine-learning/)
#
# [Towards Data Science](https://towardsdatascience.com/machine-learning-with-python-easy-and-robust-method-to-fit-nonlinear-data-19e8a1ddbd49)
#
# [Medium - ITBodhi](https://medium.com/@itbodhi/overfitting-and-underfitting-in-machine-learning-models-76cb60dbdaf6)
#
# <img src='https://miro.medium.com/max/560/1*67HOjsCZVzE6FFM7TuSBmw.jpeg'>
#
# <img src='https://miro.medium.com/max/1920/1*Lsg_bRYztO3D19w36_g7BQ.jpeg' width='550px' height='400px'>

# %% [markdown]
# #### **De Volta à Aula**
# ---

# %% [markdown]
# O modelo de Árvore de Decisão é poderoso e simples de ser implementado, mas tende a ser suscetível a ***overfit***.
#
# Um modelo alternativo, menos suscetível a ***overfit*** é o **`RandomForestClassifier`**, que simula uma floresta de árvores de decisão.
#
# Enquanto o ***Decision Tree*** busca selecionar os dados que vão ser usados para fazer os *splits* de forma a manter o equilíbrio da árvore, olhando para todas as variáveis, o modelo de ***Random Forest*** monta grupos menores de variáveis de forma aleatória e prepara várias árvores a partir desses grupos diferentes.

# %%
teste_lista = []
treino_lista = []

for i in range(1,15):
    modelo_arvore_i = RandomForestClassifier(max_depth=i)
    teste, treino = roda_modelo_cv_v3(modelo_arvore_i, dados_limpos, 5, 10)
    teste_lista.append(teste)
    treino_lista.append(treino)

# %%
x = range(1,15)
fig, ax = plt.subplots(figsize=(12,6))
plt.suptitle('Comparação AUC Médio Previsão x Treino - Random Forest', fontsize = 25, fontweight='bold')
plt.plot(x, teste_lista, color = 'darkblue', lw = 2, label='Dados de Teste')
plt.plot(x, treino_lista, color = 'orange', lw = 2, label='Dados de Treino')
plt.xlabel('Nº de Iterações',
             fontsize=15, fontweight = 'bold')
plt.ylabel('AUC Médio',
             fontsize=15, fontweight = 'bold')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.00%}'))
plt.legend(fontsize = 15, loc='upper right',bbox_to_anchor=(1.3, 1))
plt.ylim(0,1.1)
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
plt.show()

# %% [markdown]
# No caso do **Random Forest**, temos um outro parâmetro que é bem importante para a realização de iterações que é o **`n_estimators`**, que dá o número de árvores da floresta. Quanto mais árvores, mais difícil de termos ***overfit***, mas mais demorado fica o treinamento do modelo.
#
# O valor *default* é 100, mas vamos fazer alguns testes para verificar o impacto.

# %%
teste_lista = []
treino_lista = []

x = [10, 50, 100, 200]

for i in x:
    modelo_arvore_i = RandomForestClassifier(n_estimators=i)
    teste, treino = roda_modelo_cv_v3(modelo_arvore_i, dados_limpos, 5, 10)
    teste_lista.append(teste)
    treino_lista.append(treino)

# %%
fig, ax = plt.subplots(figsize=(12,6))
plt.suptitle('Comparação AUC Médio Previsão x Treino - Random Forest variando n_estimators', fontsize = 25, fontweight='bold')
plt.plot(x, teste_lista, color = 'darkblue', lw = 2, label='Dados de Teste')
plt.plot(x, treino_lista, color = 'orange', lw = 2, label='Dados de Treino')
plt.xlabel('n_estimators',
             fontsize=15, fontweight = 'bold')
plt.ylabel('AUC Médio',
             fontsize=15, fontweight = 'bold')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.00%}'))
plt.legend(fontsize = 15, loc='upper right',bbox_to_anchor=(1.3, 1))
plt.ylim(0,1.1)
ax.xaxis.set_major_locator(ticker.FixedLocator(x))
plt.show()

# %% [markdown]
# #### **Desafio - Escolher um Modelo de *Machine Learning*, Estudar Seus Hiperparâmetros e Testar com Vários Valores**
# ---
#
# Thiago comentou que dentro da documentação do **`sklearn`** tem maneiras de encontrar os melhores parâmetros para o modelo, em vez de ficar rodando repetidas vezes.
#
# [sklearn Grid Search](https://scikit-learn.org/stable/modules/grid_search.html)
#
# [Towards Data Science](https://towardsdatascience.com/random-forest-in-python-24d0893d51c0)
#
# [datacamp.com](https://www.datacamp.com/community/tutorials/random-forests-classifier-python)

# %% [markdown]
# #### **Desafio - Pesquisar Como Salvar um Modelo Treinado**
# ---

# %% [markdown]
# Encontrei duas maneiras [aqui](https://machinelearningmastery.com/save-load-machine-learning-models-python-scikit-learn/).
#
# Usando o ***pickle***:

# %%
import pickle

filename = 'modelo_arvore_final_pi.sav'
pickle.dump(modelo_arvore, open(filename, 'wb'))

# %% [markdown]
# Ou usando o ***joblib***:

# %%
import joblib

filename = 'modelo_arvore_final_jl.sav'
joblib.dump(modelo_arvore, filename)
# Out:
# ['modelo_arvore_final_jl.sav']

# %% [markdown]
# ### **O que aprendemos nessa aula?**
# ---
#
# >* O que é ***Overfit***;
# >
# >* Como Verificar o ***Overfit***;
# >
# >* Usar o Algoritmo de ***RandomForest***.
#
# ---

# %% [markdown]
# ## **Aula 06 - Finalizando a Validação**
# ---

# %% [markdown]
# **NOTA:** Um ponto de atenção é não utilizar a coluna **`PATIENT_VISIT_IDENTIFIER`** nos treinamentos dos seus modelos, isso porque essa informação não é relevante para a predição do paciente ir ou não para UTI e manter essa informação no seu **x**, pode influenciar nos resultados.
#
# Recomendo fazer isso dentro das funções `roda_modelo` e `roda_modelo_cv`, porque lá já estamos retirando as colunas **`ICU`** e **`WINDOW`** da construção do nosso **x**.

# %% [markdown]
# Um dos pontos que pode atrapalhar a elaboração do modelo e levar ao ***overfit*** é a alta correlação entre algumas variáveis.
#
# Para melhorar isso, podemos remover variáveis que tenham alta correlação.
#
# O primeiro passo é gerar a matriz de correlação de nossos dados. Mas não faz sentido calcularmos a correlação de dados não numéricos como o identificador do paciente, por exemplo. Vamos verificar a composição do nosso *dataset*.

# %%
dados_limpos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 352 entries, (0, 0) to (384, 1920)
# Columns: 231 entries, PATIENT_VISIT_IDENTIFIER to ICU
# dtypes: float64(225), int64(4), int8(1), object(1)
# memory usage: 659.8+ KB

# %% [markdown]
# Temos a distribuição por tipo das 231 colunas do *dataset*. As colunas do tipo *float64* deverão ser investigadas para a correlação, mas vamos ver o que são as demais.

# %%
dados_limpos.select_dtypes(exclude='float64')
# Out:
#                                PATIENT_VISIT_IDENTIFIER  ...  ICU
# PATIENT_VISIT_IDENTIFIER                                 ...
# 0                        0                            0  ...    1
# 2                        10                           2  ...    1
# 3                        15                           3  ...    0
# 4                        20                           4  ...    0
# 5                        25                           5  ...    0
# ...                                                 ...  ...  ...
# 380                      1900                       380  ...    1
# 381                      1905                       381  ...    0
# 382                      1910                       382  ...    1
# 383                      1915                       383  ...    0
# 384                      1920                       384  ...    0
#
# [352 rows x 6 columns]

# %% [markdown]
# São colunas que podem ficar de fora da nossa análise de correlação.
#
# São as 4 colunas iniciais e as 2 finais de nosso *dataset*.

# %%
matriz_corr = dados_limpos.iloc[:,4:-2].corr().abs()
matriz_corr
# Out:
#                                  DISEASE GROUPING 1  ...  OXYGEN_SATURATION_DIFF_REL
# DISEASE GROUPING 1                         1.000000  ...                    0.056984
# DISEASE GROUPING 2                         0.196347  ...                    0.099019
# DISEASE GROUPING 3                         0.278271  ...                    0.006110
# DISEASE GROUPING 4                         0.017529  ...                    0.025072
# DISEASE GROUPING 5                         0.340370  ...                    0.097014
# ...                                             ...  ...                         ...
# BLOODPRESSURE_SISTOLIC_DIFF_REL            0.054745  ...                    0.479010
# HEART_RATE_DIFF_REL                        0.093512  ...                    0.350001
# RESPIRATORY_RATE_DIFF_REL                  0.052568  ...                    0.342852
# TEMPERATURE_DIFF_REL                       0.039692  ...                    0.493818
# OXYGEN_SATURATION_DIFF_REL                 0.056984  ...                    1.000000
#
# [225 rows x 225 columns]

# %% [markdown]
# Podemos ver que a matriz de correlação se repete, ela fica "espelhada" a partir da diagonal onde as variáveis se correlacionam com elas mesmas (resultado sempre é 1).
#
# Vamos então "limpar" essa matriz para ficar só com o triângulo superior da matriz, sem a diagonal principal.

# %%
dimensoes = matriz_corr.shape
matriz_de_uns = np.ones(dimensoes)
triang_sem_diag = np.triu(matriz_de_uns, k = 1).astype(np.bool)
matriz_superior = matriz_corr.where(triang_sem_diag)
matriz_superior
# Out:
#                                  DISEASE GROUPING 1  ...  OXYGEN_SATURATION_DIFF_REL
# DISEASE GROUPING 1                              NaN  ...                    0.056984
# DISEASE GROUPING 2                              NaN  ...                    0.099019
# DISEASE GROUPING 3                              NaN  ...                    0.006110
# DISEASE GROUPING 4                              NaN  ...                    0.025072
# DISEASE GROUPING 5                              NaN  ...                    0.097014
# ...                                             ...  ...                         ...
# BLOODPRESSURE_SISTOLIC_DIFF_REL                 NaN  ...                    0.479010
# HEART_RATE_DIFF_REL                             NaN  ...                    0.350001
# RESPIRATORY_RATE_DIFF_REL                       NaN  ...                    0.342852
# TEMPERATURE_DIFF_REL                            NaN  ...                    0.493818
# OXYGEN_SATURATION_DIFF_REL                      NaN  ...                         NaN
#
# [225 rows x 225 columns]

# %%
alta_corr = 0.95

vars_correlacionadas = [coluna for coluna in matriz_superior.columns if any(matriz_superior[coluna] > alta_corr)]
print(len(vars_correlacionadas))
print(vars_correlacionadas)
# Out:
# 131
# ['ALBUMIN_MEAN', 'ALBUMIN_MIN', 'ALBUMIN_MAX', 'BE_ARTERIAL_MEAN', 'BE_ARTERIAL_MIN', 'BE_ARTERIAL_MAX', 'BE_VENOUS_MEAN', 'BE_VENOUS_MIN', 'BE_VENOUS_MAX', 'BIC_ARTERIAL_MEAN', 'BIC_ARTERIAL_MIN', 'BIC_ARTERIAL_MAX', 'BIC_VENOUS_MEAN', 'BIC_VENOUS_MIN', 'BIC_VENOUS_MAX', 'BILLIRUBIN_MEAN', 'BILLIRUBIN_MIN', 'BILLIRUBIN_MAX', 'BLAST_MEAN', 'BLAST_MIN', 'BLAST_MAX', 'CALCIUM_MEAN', 'CALCIUM_MIN', 'CALCIUM_MAX', 'CREATININ_MEAN', 'CREATININ_MIN', 'CREATININ_MAX', 'FFA_MEAN', 'FFA_MIN', 'FFA_MAX', 'GGT_MEAN', 'GGT_MIN', 'GGT_MAX', 'GLUCOSE_MEAN', 'GLUCOSE_MIN', 'GLUCOSE_MAX', 'HEMATOCRITE_MEAN', 'HEMATOCRITE_MIN', 'HEMATOCRITE_MAX', 'HEMOGLOBIN_MEDIAN', 'HEMOGLOBIN_MEAN', 'HEMOGLOBIN_MIN', 'HEMOGLOBIN_MAX', 'INR_MEAN', 'INR_MIN', 'INR_MAX', 'LACTATE_MEAN', 'LACTATE_MIN', 'LACTATE_MAX', 'LEUKOCYTES_MEAN', 'LEUKOCYTES_MIN', 'LEUKOCYTES_MAX', 'LINFOCITOS_MEAN', 'LINFOCITOS_MIN', 'LINFOCITOS_MAX', 'NEUTROPHILES_MEDIAN', 'NEUTROPHILES_MEAN', 'NEUTROPHILES_MIN', 'NEUTROPHILES_MAX', 'P02_ARTERIAL_MEAN', 'P02_ARTERIAL_MIN', 'P02_ARTERIAL_MAX', 'P02_VENOUS_MEAN', 'P02_VENOUS_MIN', 'P02_VENOUS_MAX', 'PC02_ARTERIAL_MEAN', 'PC02_ARTERIAL_MIN', 'PC02_ARTERIAL_MAX', 'PC02_VENOUS_MEAN', 'PC02_VENOUS_MIN', 'PC02_VENOUS_MAX', 'PCR_MEAN', 'PCR_MIN', 'PCR_MAX', 'PH_ARTERIAL_MEAN', 'PH_ARTERIAL_MIN', 'PH_ARTERIAL_MAX', 'PH_VENOUS_MEAN', 'PH_VENOUS_MIN', 'PH_VENOUS_MAX', 'PLATELETS_MEAN', 'PLATELETS_MIN', 'PLATELETS_MAX', 'POTASSIUM_MEAN', 'POTASSIUM_MIN', 'POTASSIUM_MAX', 'SAT02_ARTERIAL_MEAN', 'SAT02_ARTERIAL_MIN', 'SAT02_ARTERIAL_MAX', 'SAT02_VENOUS_MEAN', 'SAT02_VENOUS_MIN', 'SAT02_VENOUS_MAX', 'SODIUM_MEAN', 'SODIUM_MIN', 'SODIUM_MAX', 'TGO_MEAN', 'TGO_MIN', 'TGO_MAX', 'TGP_MEAN', 'TGP_MIN', 'TGP_MAX', 'TTPA_MEAN', 'TTPA_MIN', 'TTPA_MAX', 'UREA_MEAN', 'UREA_MIN', 'UREA_MAX', 'DIMER_MEAN', 'DIMER_MIN', 'DIMER_MAX', 'BLOODPRESSURE_DIASTOLIC_MEDIAN', 'BLOODPRESSURE_SISTOLIC_MEDIAN', 'HEART_RATE_MEDIAN', 'RESPIRATORY_RATE_MEDIAN', 'TEMPERATURE_MEDIAN', 'OXYGEN_SATURATION_MEDIAN', 'BLOODPRESSURE_DIASTOLIC_MIN', 'BLOODPRESSURE_SISTOLIC_MIN', 'HEART_RATE_MIN', 'TEMPERATURE_MIN', 'OXYGEN_SATURATION_MIN', 'BLOODPRESSURE_SISTOLIC_MAX', 'HEART_RATE_MAX', 'RESPIRATORY_RATE_MAX', 'TEMPERATURE_MAX', 'OXYGEN_SATURATION_MAX', 'BLOODPRESSURE_DIASTOLIC_DIFF_REL', 'BLOODPRESSURE_SISTOLIC_DIFF_REL', 'RESPIRATORY_RATE_DIFF_REL', 'TEMPERATURE_DIFF_REL', 'OXYGEN_SATURATION_DIFF_REL']

# %% [markdown]
# Vamos agora fazer uma função que execute essa matriz de correlação, identifique as colunas que apresentem uma correlação superior a uma nota de corte que iremos definir e retire essas colunas de nosso *dataset*.

# %%
def remove_vars_correlacionadas(dados, valor_corte):
    matriz_corr = dados.iloc[:,4:-2].corr().abs()
    matriz_superior = matriz_corr.where(np.triu(np.ones(matriz_corr.shape), k = 1).astype(np.bool))
    vars_correlacionadas = [coluna for coluna in matriz_superior.columns if any(matriz_superior[coluna] > valor_corte)]

    return dados.drop(vars_correlacionadas, axis = 1)

# %%
dados_limpos_sem_corr = remove_vars_correlacionadas(dados_limpos, 0.95)
dados_limpos_sem_corr
# Out:
#                                PATIENT_VISIT_IDENTIFIER  ...  ICU
# PATIENT_VISIT_IDENTIFIER                                 ...
# 0                        0                            0  ...    1
# 2                        10                           2  ...    1
# 3                        15                           3  ...    0
# 4                        20                           4  ...    0
# 5                        25                           5  ...    0
# ...                                                 ...  ...  ...
# 380                      1900                       380  ...    1
# 381                      1905                       381  ...    0
# 382                      1910                       382  ...    1
# 383                      1915                       383  ...    0
# 384                      1920                       384  ...    0
#
# [352 rows x 100 columns]

# %%
roda_modelo_cv_v3(modelo_arvore, dados_limpos, 5, 10)
# Out:
# (0.6279279683391525, 1.0)

# %%
roda_modelo_cv_v3(modelo_arvore, dados_limpos_sem_corr, 5, 10)
# Out:
# (0.6212003211345317, 1.0)

# %%
modelo_arvore_i = DecisionTreeClassifier(max_depth=3)
roda_modelo_cv_v3(modelo_arvore_i, dados_limpos, 5, 10)
# Out:
# (0.6643847795163584, 0.8243714304989842)

# %%
roda_modelo_cv_v3(modelo_arvore_i, dados_limpos_sem_corr, 5, 10)
# Out:
# (0.6634075822233717, 0.8231778726293808)

# %%
teste_lista_limpos = []
treino_lista_limpos = []

for i in range(1,15):
    modelo_arvore_i = DecisionTreeClassifier(max_depth=i)
    teste, treino = roda_modelo_cv_v3(modelo_arvore_i, dados_limpos, 5, 10)
    teste_lista_limpos.append(teste)
    treino_lista_limpos.append(treino)

teste_lista_limpos_sem_corr = []
treino_lista_limpos_sem_corr = []

for i in range(1,15):
    modelo_arvore_i = DecisionTreeClassifier(max_depth=i)
    teste, treino = roda_modelo_cv_v3(modelo_arvore_i, dados_limpos_sem_corr, 5, 10)
    teste_lista_limpos_sem_corr.append(teste)
    treino_lista_limpos_sem_corr.append(treino)

# %%
fig, ax = plt.subplots(figsize=(12,6))

x = range(1,15)

plt.suptitle('Comparação AUC Médio Previsão x Treino - Random Forest', fontsize = 25, fontweight='bold')
plt.plot(x, teste_lista_limpos, color = 'darkblue', lw = 2, label = 'Dados de Teste Limpos')
plt.plot(x, treino_lista_limpos, color = 'orange', lw = 2, label = 'Dados de Treino Limpos')
plt.plot(x, teste_lista_limpos_sem_corr, color = 'xkcd:aqua blue', lw = 2, ls = '--', label = 'Dados de Teste Limpos Sem Corr')
plt.plot(x, treino_lista_limpos_sem_corr, color = 'xkcd:tomato', lw = 2, ls = '--', label = 'Dados de Treino Limpos Sem Corr')

plt.xlabel('Nº de Iterações',
             fontsize=15, fontweight = 'bold')
plt.ylabel('AUC Médio',
             fontsize=15, fontweight = 'bold')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.00%}'))
plt.legend(fontsize = 15, loc='upper right',bbox_to_anchor=(1.5, 1))
plt.ylim(0,1.1)
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
plt.show()

# %% [markdown]
# #### **Desafio - Pesquisar no `sklearn` Sobre *feature selection* e *feature importance***
# ---

# %% [markdown]
# #### **Desafio - Plotar a Matriz de Confusão**
# ---

# %% [markdown]
# #### **Desafio - Retomar o Desafio da Aula Passada de Testar Vários Hiperparâmetros, Agora na Base Sem Correlações**
# ---

# %% [markdown]
# #### **Desafio Extra - Criar um *Pipeline* de Treinamento**
# ---

# %% [markdown]
# ### **Para saber mais: Otimização de Parâmetros**
# ---

# %% [markdown]
# O próprio **`sklearn`** oferece maneiras de se buscar a otimização dos parâmetros a serem usados em nosso modelo, de duas maneiras.
#
# * ***GridSearchCV*** onde passamos um dicionário com os parâmetros a serem testados e teremos diversas iterações do modelo com diferentes combinações dos mesmos. Ao final, temos um *dataset* onde podemos analisar os resultados obtidos a partir de cada conjunto de parâmetros testados
#
# * ***RandomizedSearchCV*** onde passamos um dicionário com os parâmetros a serem testados e estabelecemos a quantidade de iterações que queremos testar. Dessa forma podemos passar *ranges* de parâmetros que serão testados aleatoriamente
#
# Vamos começar pelo ***GridSearchCV***.

# %%
from sklearn.model_selection import GridSearchCV

def roda_modelo_GridSearchCV(modelo, dados, n_splits, n_repeats, espaco_de_parametros):

    np.random.seed(1231234)
    dados = dados.sample(frac=1).reset_index(drop=True)
    x_columns = dados.columns
    y = dados['ICU']
    x = dados[x_columns].drop(['ICU','WINDOW'], axis=1)


    cv = RepeatedStratifiedKFold(n_splits = n_splits, n_repeats=n_repeats)

    busca = GridSearchCV(modelo, param_grid=espaco_de_parametros,
                         cv = cv, scoring='roc_auc',
                         return_train_score=True)
    busca.fit(x, y)

    resultados = pd.DataFrame(busca.cv_results_)

    auc_medio = resultados.iloc[busca.best_index_]['mean_test_score']
    auc_medio_treino = resultados.iloc[busca.best_index_]['mean_train_score']

    auc_std = resultados.iloc[busca.best_index_]['std_test_score']

    print(f'AUC  {auc_medio} - {auc_medio_treino}')
    return auc_medio, auc_medio_treino, resultados, busca

# %%
espaco_de_parametros_grid = {
  "max_depth" : [3, 5],
  "min_samples_split" : [32, 64, 128],
  "min_samples_leaf" : [32, 64, 128],
  "criterion" : ["gini", "entropy"]
}

# %%
auc_medio_grid, auc_medio_treino_grid, resultados_grid, busca_grid = roda_modelo_GridSearchCV(mod_RFC, dados_limpos_sem_corr, 10, 10, espaco_de_parametros_grid)
# Out:
# AUC  0.8034825421396629 - 0.8573069445995174

# %%
resultados_grid
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.150304      0.006863         0.012035        0.002158
# 1        0.150904      0.006560         0.011620        0.001451
# 2        0.146904      0.006250         0.011866        0.001981
# 3        0.147218      0.007208         0.011939        0.001736
# 4        0.152532      0.009156         0.012444        0.001826
# 5        0.152139      0.010084         0.012751        0.002655
# 6        0.139365      0.007331         0.011567        0.001839
# 7        0.138603      0.007405         0.011613        0.001924
# 8        0.137219      0.006603         0.011079        0.001325
# 9        0.149079      0.005765         0.011651        0.001596
# 10       0.149640      0.006040         0.011393        0.001760
# 11       0.144703      0.006779         0.011476        0.001488
# 12       0.142463      0.006361         0.011476        0.001647
# 13       0.143379      0.006584         0.011479        0.001506
# 14       0.143584      0.007031         0.011754        0.001846
# 15       0.136018      0.007006         0.011162        0.001374
# 16       0.137388      0.006954         0.011342        0.001394
# 17       0.136143      0.006517         0.011319        0.001699
# 18       0.152215      0.006044         0.011718        0.001549
# 19       0.151777      0.004845         0.011968        0.001945
# 20       0.150192      0.006096         0.011637        0.001267
# 21       0.144961      0.005618         0.011805        0.001724
# 22       0.146178      0.006602         0.011786        0.001716
# 23       0.143798      0.005855         0.011446        0.001443
# 24       0.135707      0.005652         0.011309        0.001323
# 25       0.137066      0.007293         0.011457        0.001861
# 26       0.137904      0.006837         0.011624        0.001668
# 27       0.151626      0.005242         0.011810        0.001803
# 28       0.153330      0.007248         0.011744        0.001819
# 29       0.149467      0.007232         0.011940        0.001934
# 30       0.144649      0.007287         0.011405        0.001341
# 31       0.143597      0.005860         0.011251        0.001384
# 32       0.143337      0.005846         0.011765        0.002066
# 33       0.136705      0.005761         0.011386        0.001768
# 34       0.136902      0.005730         0.011723        0.001928
# 35       0.137460      0.006369         0.011295        0.001623
#
#    param_criterion param_max_depth param_min_samples_leaf  \
# 0             gini               3                     32
# 1             gini               3                     32
# 2             gini               3                     32
# 3             gini               3                     64
# 4             gini               3                     64
# 5             gini               3                     64
# 6             gini               3                    128
# 7             gini               3                    128
# 8             gini               3                    128
# 9             gini               5                     32
# 10            gini               5                     32
# 11            gini               5                     32
# 12            gini               5                     64
# 13            gini               5                     64
# 14            gini               5                     64
# 15            gini               5                    128
# 16            gini               5                    128
# 17            gini               5                    128
# 18         entropy               3                     32
# 19         entropy               3                     32
# 20         entropy               3                     32
# 21         entropy               3                     64
# 22         entropy               3                     64
# 23         entropy               3                     64
# 24         entropy               3                    128
# 25         entropy               3                    128
# 26         entropy               3                    128
# 27         entropy               5                     32
# 28         entropy               5                     32
# 29         entropy               5                     32
# 30         entropy               5                     64
# 31         entropy               5                     64
# 32         entropy               5                     64
# 33         entropy               5                    128
# 34         entropy               5                    128
# 35         entropy               5                    128
#
#    param_min_samples_split  \
# 0                       32
# 1                       64
# 2                      128
# 3                       32
# 4                       64
# 5                      128
# 6                       32
# 7                       64
# 8                      128
# 9                       32
# 10                      64
# 11                     128
# 12                      32
# 13                      64
# 14                     128
# 15                      32
# 16                      64
# 17                     128
# 18                      32
# 19                      64
# 20                     128
# 21                      32
# 22                      64
# 23                     128
# 24                      32
# 25                      64
# 26                     128
# 27                      32
# 28                      64
# 29                     128
# 30                      32
# 31                      64
# 32                     128
# 33                      32
# 34                      64
# 35                     128
#
#                                                                                          params  \
# 0        {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 32, 'min_samples_split': 32}
# 1        {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 32, 'min_samples_split': 64}
# 2       {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 32, 'min_samples_split': 128}
# 3        {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 64, 'min_samples_split': 32}
# 4        {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 64, 'min_samples_split': 64}
# 5       {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 64, 'min_samples_split': 128}
# 6       {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 128, 'min_samples_split': 32}
# 7       {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 128, 'min_samples_split': 64}
# 8      {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 128, 'min_samples_split': 128}
# 9        {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 32, 'min_samples_split': 32}
# 10       {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 32, 'min_samples_split': 64}
# 11      {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 32, 'min_samples_split': 128}
# 12       {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 64, 'min_samples_split': 32}
# 13       {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 64, 'min_samples_split': 64}
# 14      {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 64, 'min_samples_split': 128}
# 15      {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 128, 'min_samples_split': 32}
# 16      {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 128, 'min_samples_split': 64}
# 17     {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 128, 'min_samples_split': 128}
# 18    {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 32, 'min_samples_split': 32}
# 19    {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 32, 'min_samples_split': 64}
# 20   {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 32, 'min_samples_split': 128}
# 21    {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 64, 'min_samples_split': 32}
# 22    {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 64, 'min_samples_split': 64}
# 23   {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 64, 'min_samples_split': 128}
# 24   {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 128, 'min_samples_split': 32}
# 25   {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 128, 'min_samples_split': 64}
# 26  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 128, 'min_samples_split': 128}
# 27    {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 32, 'min_samples_split': 32}
# 28    {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 32, 'min_samples_split': 64}
# 29   {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 32, 'min_samples_split': 128}
# 30    {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 64, 'min_samples_split': 32}
# 31    {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 64, 'min_samples_split': 64}
# 32   {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 64, 'min_samples_split': 128}
# 33   {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 128, 'min_samples_split': 32}
# 34   {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 128, 'min_samples_split': 64}
# 35  {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 128, 'min_samples_split': 128}
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0            0.817337           0.712074           0.796053
# 1            0.789474           0.755418           0.838816
# 2            0.808050           0.746130           0.871711
# 3            0.820433           0.671827           0.842105
# 4            0.811146           0.727554           0.815789
# 5            0.823529           0.727554           0.828947
# 6            0.500000           0.500000           0.500000
# 7            0.500000           0.500000           0.500000
# 8            0.500000           0.500000           0.500000
# 9            0.792570           0.758514           0.855263
# 10           0.814241           0.755418           0.858553
# 11           0.792570           0.730650           0.792763
# 12           0.814241           0.693498           0.805921
# 13           0.798762           0.736842           0.815789
# 14           0.839009           0.746130           0.832237
# 15           0.500000           0.500000           0.500000
# 16           0.500000           0.500000           0.500000
# 17           0.500000           0.500000           0.500000
# 18           0.804954           0.752322           0.809211
# 19           0.817337           0.721362           0.861842
# 20           0.801858           0.746130           0.838816
# 21           0.792570           0.705882           0.822368
# 22           0.795666           0.749226           0.805921
# 23           0.801858           0.724458           0.819079
# 24           0.500000           0.500000           0.500000
# 25           0.500000           0.500000           0.500000
# 26           0.500000           0.500000           0.500000
# 27           0.804954           0.724458           0.851974
# 28           0.823529           0.712074           0.822368
# 29           0.795666           0.761610           0.855263
# 30           0.798762           0.702786           0.838816
# 31           0.792570           0.696594           0.865132
# 32           0.820433           0.681115           0.832237
# 33           0.500000           0.500000           0.500000
# 34           0.500000           0.500000           0.500000
# 35           0.500000           0.500000           0.500000
#
#     split3_test_score  split4_test_score  split5_test_score  \
# 0            0.845395           0.746711           0.792763
# 1            0.851974           0.713816           0.805921
# 2            0.891447           0.750000           0.842105
# 3            0.736842           0.687500           0.766447
# 4            0.855263           0.717105           0.766447
# 5            0.789474           0.707237           0.743421
# 6            0.500000           0.500000           0.500000
# 7            0.500000           0.500000           0.500000
# 8            0.500000           0.500000           0.500000
# 9            0.865132           0.766447           0.792763
# 10           0.851974           0.730263           0.750000
# 11           0.835526           0.743421           0.766447
# 12           0.822368           0.661184           0.773026
# 13           0.799342           0.717105           0.789474
# 14           0.815789           0.694079           0.786184
# 15           0.500000           0.500000           0.500000
# 16           0.500000           0.500000           0.500000
# 17           0.500000           0.500000           0.500000
# 18           0.855263           0.680921           0.763158
# 19           0.845395           0.776316           0.776316
# 20           0.838816           0.759868           0.832237
# 21           0.848684           0.700658           0.786184
# 22           0.776316           0.674342           0.832237
# 23           0.815789           0.680921           0.730263
# 24           0.500000           0.500000           0.500000
# 25           0.500000           0.500000           0.500000
# 26           0.500000           0.500000           0.500000
# 27           0.868421           0.756579           0.835526
# 28           0.845395           0.759868           0.759868
# 29           0.868421           0.703947           0.789474
# 30           0.815789           0.710526           0.726974
# 31           0.805921           0.697368           0.776316
# 32           0.802632           0.690789           0.776316
# 33           0.500000           0.500000           0.500000
# 34           0.500000           0.500000           0.500000
# 35           0.500000           0.500000           0.500000
#
#     split6_test_score  split7_test_score  split8_test_score  \
# 0            0.878289           0.865132           0.565789
# 1            0.884868           0.855263           0.601974
# 2            0.891447           0.875000           0.608553
# 3            0.858553           0.809211           0.582237
# 4            0.891447           0.825658           0.582237
# 5            0.878289           0.822368           0.562500
# 6            0.500000           0.500000           0.500000
# 7            0.500000           0.500000           0.500000
# 8            0.500000           0.500000           0.500000
# 9            0.884868           0.875000           0.588816
# 10           0.881579           0.835526           0.608553
# 11           0.888158           0.842105           0.578947
# 12           0.878289           0.845395           0.565789
# 13           0.884868           0.838816           0.513158
# 14           0.875000           0.815789           0.582237
# 15           0.500000           0.500000           0.500000
# 16           0.500000           0.500000           0.500000
# 17           0.500000           0.500000           0.500000
# 18           0.868421           0.835526           0.595395
# 19           0.881579           0.851974           0.578947
# 20           0.884868           0.838816           0.598684
# 21           0.848684           0.835526           0.569079
# 22           0.871711           0.819079           0.532895
# 23           0.878289           0.756579           0.536184
# 24           0.500000           0.500000           0.500000
# 25           0.500000           0.500000           0.500000
# 26           0.500000           0.500000           0.500000
# 27           0.884868           0.855263           0.555921
# 28           0.871711           0.878289           0.585526
# 29           0.878289           0.891447           0.585526
# 30           0.858553           0.802632           0.565789
# 31           0.815789           0.825658           0.546053
# 32           0.858553           0.802632           0.555921
# 33           0.500000           0.500000           0.500000
# 34           0.500000           0.500000           0.500000
# 35           0.500000           0.500000           0.500000
#
#     split9_test_score  split10_test_score  split11_test_score  \
# 0            0.830065            0.839009            0.622291
# 1            0.869281            0.820433            0.591331
# 2            0.830065            0.792570            0.575851
# 3            0.813725            0.783282            0.520124
# 4            0.859477            0.792570            0.507740
# 5            0.833333            0.848297            0.585139
# 6            0.500000            0.500000            0.500000
# 7            0.500000            0.500000            0.500000
# 8            0.500000            0.500000            0.500000
# 9            0.849673            0.808050            0.566563
# 10           0.862745            0.792570            0.569659
# 11           0.843137            0.804954            0.600619
# 12           0.852941            0.780186            0.538700
# 13           0.836601            0.798762            0.551084
# 14           0.836601            0.804954            0.557276
# 15           0.500000            0.500000            0.500000
# 16           0.500000            0.500000            0.500000
# 17           0.500000            0.500000            0.500000
# 18           0.846405            0.804954            0.554180
# 19           0.856209            0.789474            0.594427
# 20           0.836601            0.780186            0.572755
# 21           0.833333            0.808050            0.585139
# 22           0.839869            0.798762            0.575851
# 23           0.823529            0.826625            0.578947
# 24           0.500000            0.500000            0.500000
# 25           0.500000            0.500000            0.500000
# 26           0.500000            0.500000            0.500000
# 27           0.882353            0.808050            0.625387
# 28           0.846405            0.786378            0.566563
# 29           0.836601            0.823529            0.659443
# 30           0.830065            0.783282            0.578947
# 31           0.810458            0.811146            0.517028
# 32           0.833333            0.795666            0.554180
# 33           0.500000            0.500000            0.500000
# 34           0.500000            0.500000            0.500000
# 35           0.500000            0.500000            0.500000
#
#     split12_test_score  split13_test_score  split14_test_score  \
# 0             0.848684            0.858553            0.802632
# 1             0.842105            0.878289            0.809211
# 2             0.828947            0.835526            0.819079
# 3             0.832237            0.832237            0.759868
# 4             0.822368            0.828947            0.707237
# 5             0.842105            0.802632            0.713816
# 6             0.500000            0.500000            0.500000
# 7             0.500000            0.500000            0.500000
# 8             0.500000            0.500000            0.500000
# 9             0.828947            0.851974            0.779605
# 10            0.845395            0.845395            0.819079
# 11            0.871711            0.832237            0.832237
# 12            0.855263            0.809211            0.746711
# 13            0.838816            0.779605            0.717105
# 14            0.799342            0.796053            0.753289
# 15            0.500000            0.500000            0.500000
# 16            0.500000            0.500000            0.500000
# 17            0.500000            0.500000            0.500000
# 18            0.875000            0.868421            0.809211
# 19            0.838816            0.861842            0.805921
# 20            0.842105            0.845395            0.763158
# 21            0.822368            0.799342            0.713816
# 22            0.799342            0.825658            0.773026
# 23            0.769737            0.779605            0.730263
# 24            0.500000            0.500000            0.500000
# 25            0.500000            0.500000            0.500000
# 26            0.500000            0.500000            0.500000
# 27            0.861842            0.825658            0.819079
# 28            0.848684            0.851974            0.799342
# 29            0.828947            0.835526            0.805921
# 30            0.812500            0.838816            0.773026
# 31            0.851974            0.802632            0.763158
# 32            0.789474            0.766447            0.789474
# 33            0.500000            0.500000            0.500000
# 34            0.500000            0.500000            0.500000
# 35            0.500000            0.500000            0.500000
#
#     split15_test_score  split16_test_score  split17_test_score  \
# 0             0.769737            0.858553            0.799342
# 1             0.730263            0.825658            0.786184
# 2             0.776316            0.819079            0.769737
# 3             0.730263            0.743421            0.740132
# 4             0.736842            0.792763            0.740132
# 5             0.717105            0.812500            0.756579
# 6             0.500000            0.500000            0.500000
# 7             0.500000            0.500000            0.500000
# 8             0.500000            0.500000            0.500000
# 9             0.743421            0.832237            0.773026
# 10            0.717105            0.825658            0.802632
# 11            0.730263            0.825658            0.756579
# 12            0.763158            0.792763            0.746711
# 13            0.710526            0.792763            0.730263
# 14            0.759868            0.812500            0.733553
# 15            0.500000            0.500000            0.500000
# 16            0.500000            0.500000            0.500000
# 17            0.500000            0.500000            0.500000
# 18            0.717105            0.828947            0.799342
# 19            0.726974            0.812500            0.786184
# 20            0.720395            0.822368            0.805921
# 21            0.740132            0.842105            0.776316
# 22            0.707237            0.812500            0.723684
# 23            0.723684            0.805921            0.710526
# 24            0.500000            0.500000            0.500000
# 25            0.500000            0.500000            0.500000
# 26            0.500000            0.500000            0.500000
# 27            0.776316            0.845395            0.763158
# 28            0.743421            0.828947            0.746711
# 29            0.684211            0.851974            0.789474
# 30            0.700658            0.789474            0.720395
# 31            0.763158            0.799342            0.766447
# 32            0.740132            0.835526            0.743421
# 33            0.500000            0.500000            0.500000
# 34            0.500000            0.500000            0.500000
# 35            0.500000            0.500000            0.500000
#
#     split18_test_score  split19_test_score  split20_test_score  \
# 0             0.924342            0.764706            0.811146
# 1             0.944079            0.745098            0.786378
# 2             0.937500            0.774510            0.804954
# 3             0.944079            0.660131            0.773994
# 4             0.934211            0.640523            0.699690
# 5             0.907895            0.653595            0.712074
# 6             0.500000            0.500000            0.500000
# 7             0.500000            0.500000            0.500000
# 8             0.500000            0.500000            0.500000
# 9             0.934211            0.735294            0.789474
# 10            0.944079            0.718954            0.770898
# 11            0.914474            0.705882            0.798762
# 12            0.934211            0.656863            0.730650
# 13            0.930921            0.686275            0.764706
# 14            0.927632            0.666667            0.761610
# 15            0.500000            0.500000            0.500000
# 16            0.500000            0.500000            0.500000
# 17            0.500000            0.500000            0.500000
# 18            0.940789            0.735294            0.786378
# 19            0.930921            0.692810            0.811146
# 20            0.914474            0.722222            0.854489
# 21            0.957237            0.640523            0.755418
# 22            0.921053            0.660131            0.755418
# 23            0.944079            0.647059            0.724458
# 24            0.500000            0.500000            0.500000
# 25            0.500000            0.500000            0.500000
# 26            0.500000            0.500000            0.500000
# 27            0.950658            0.764706            0.804954
# 28            0.940789            0.712418            0.792570
# 29            0.914474            0.735294            0.820433
# 30            0.960526            0.633987            0.705882
# 31            0.950658            0.653595            0.702786
# 32            0.917763            0.673203            0.752322
# 33            0.500000            0.500000            0.500000
# 34            0.500000            0.500000            0.500000
# 35            0.500000            0.500000            0.500000
#
#     split21_test_score  split22_test_score  split23_test_score  \
# 0             0.801858            0.707237            0.828947
# 1             0.811146            0.703947            0.842105
# 2             0.770898            0.746711            0.832237
# 3             0.804954            0.654605            0.796053
# 4             0.786378            0.651316            0.756579
# 5             0.755418            0.674342            0.769737
# 6             0.500000            0.500000            0.500000
# 7             0.500000            0.500000            0.500000
# 8             0.500000            0.500000            0.500000
# 9             0.789474            0.746711            0.838816
# 10            0.792570            0.717105            0.812500
# 11            0.780186            0.743421            0.851974
# 12            0.798762            0.644737            0.819079
# 13            0.826625            0.661184            0.759868
# 14            0.823529            0.621711            0.759868
# 15            0.500000            0.500000            0.500000
# 16            0.500000            0.500000            0.500000
# 17            0.500000            0.500000            0.500000
# 18            0.770898            0.723684            0.842105
# 19            0.808050            0.740132            0.822368
# 20            0.773994            0.759868            0.845395
# 21            0.767802            0.667763            0.782895
# 22            0.798762            0.628289            0.786184
# 23            0.801858            0.680921            0.759868
# 24            0.500000            0.500000            0.500000
# 25            0.500000            0.500000            0.500000
# 26            0.500000            0.500000            0.500000
# 27            0.798762            0.710526            0.805921
# 28            0.808050            0.694079            0.828947
# 29            0.789474            0.736842            0.868421
# 30            0.801858            0.638158            0.776316
# 31            0.789474            0.654605            0.763158
# 32            0.808050            0.618421            0.769737
# 33            0.500000            0.500000            0.500000
# 34            0.500000            0.500000            0.500000
# 35            0.500000            0.500000            0.500000
#
#     split24_test_score  split25_test_score  split26_test_score  \
# 0             0.835526            0.815789            0.750000
# 1             0.828947            0.842105            0.717105
# 2             0.812500            0.855263            0.697368
# 3             0.865132            0.805921            0.661184
# 4             0.828947            0.819079            0.703947
# 5             0.828947            0.842105            0.648026
# 6             0.500000            0.500000            0.500000
# 7             0.500000            0.500000            0.500000
# 8             0.500000            0.500000            0.500000
# 9             0.838816            0.842105            0.743421
# 10            0.815789            0.855263            0.740132
# 11            0.838816            0.832237            0.690789
# 12            0.845395            0.812500            0.687500
# 13            0.792763            0.865132            0.703947
# 14            0.802632            0.835526            0.654605
# 15            0.500000            0.500000            0.500000
# 16            0.500000            0.500000            0.500000
# 17            0.500000            0.500000            0.500000
# 18            0.819079            0.835526            0.743421
# 19            0.865132            0.858553            0.713816
# 20            0.789474            0.835526            0.710526
# 21            0.848684            0.861842            0.700658
# 22            0.898026            0.858553            0.648026
# 23            0.828947            0.845395            0.671053
# 24            0.500000            0.500000            0.500000
# 25            0.500000            0.500000            0.500000
# 26            0.500000            0.500000            0.500000
# 27            0.822368            0.842105            0.717105
# 28            0.805921            0.832237            0.713816
# 29            0.815789            0.835526            0.703947
# 30            0.819079            0.832237            0.694079
# 31            0.838816            0.796053            0.680921
# 32            0.825658            0.838816            0.677632
# 33            0.500000            0.500000            0.500000
# 34            0.500000            0.500000            0.500000
# 35            0.500000            0.500000            0.500000
#
#     split27_test_score  split28_test_score  split29_test_score  \
# 0             0.631579            0.884868            0.866013
# 1             0.713816            0.907895            0.866013
# 2             0.634868            0.875000            0.849673
# 3             0.628289            0.878289            0.774510
# 4             0.631579            0.861842            0.820261
# 5             0.631579            0.904605            0.751634
# 6             0.500000            0.500000            0.500000
# 7             0.500000            0.500000            0.500000
# 8             0.500000            0.500000            0.500000
# 9             0.631579            0.894737            0.843137
# 10            0.654605            0.855263            0.856209
# 11            0.674342            0.861842            0.856209
# 12            0.641447            0.924342            0.820261
# 13            0.671053            0.898026            0.797386
# 14            0.601974            0.861842            0.794118
# 15            0.500000            0.500000            0.500000
# 16            0.500000            0.500000            0.500000
# 17            0.500000            0.500000            0.500000
# 18            0.654605            0.888158            0.839869
# 19            0.667763            0.865132            0.846405
# 20            0.671053            0.878289            0.869281
# 21            0.664474            0.878289            0.810458
# 22            0.700658            0.835526            0.790850
# 23            0.634868            0.934211            0.820261
# 24            0.500000            0.500000            0.500000
# 25            0.500000            0.500000            0.500000
# 26            0.500000            0.500000            0.500000
# 27            0.680921            0.898026            0.830065
# 28            0.598684            0.845395            0.856209
# 29            0.641447            0.851974            0.833333
# 30            0.687500            0.921053            0.790850
# 31            0.611842            0.888158            0.794118
# 32            0.684211            0.858553            0.823529
# 33            0.500000            0.500000            0.500000
# 34            0.500000            0.500000            0.500000
# 35            0.500000            0.500000            0.500000
#
#     split30_test_score  split31_test_score  split32_test_score  \
# 0             0.857585            0.851393            0.878289
# 1             0.860681            0.873065            0.875000
# 2             0.842105            0.854489            0.868421
# 3             0.804954            0.839009            0.799342
# 4             0.823529            0.789474            0.815789
# 5             0.823529            0.817337            0.822368
# 6             0.500000            0.500000            0.500000
# 7             0.500000            0.500000            0.500000
# 8             0.500000            0.500000            0.500000
# 9             0.860681            0.848297            0.888158
# 10            0.863777            0.863777            0.891447
# 11            0.842105            0.869969            0.904605
# 12            0.814241            0.835913            0.815789
# 13            0.780186            0.835913            0.838816
# 14            0.808050            0.876161            0.845395
# 15            0.500000            0.500000            0.500000
# 16            0.500000            0.500000            0.500000
# 17            0.500000            0.500000            0.500000
# 18            0.900929            0.885449            0.845395
# 19            0.857585            0.845201            0.888158
# 20            0.835913            0.863777            0.848684
# 21            0.839009            0.808050            0.828947
# 22            0.804954            0.811146            0.858553
# 23            0.842105            0.860681            0.845395
# 24            0.500000            0.500000            0.500000
# 25            0.500000            0.500000            0.500000
# 26            0.500000            0.500000            0.500000
# 27            0.857585            0.854489            0.865132
# 28            0.879257            0.863777            0.858553
# 29            0.829721            0.839009            0.832237
# 30            0.845201            0.869969            0.815789
# 31            0.876161            0.839009            0.796053
# 32            0.811146            0.829721            0.835526
# 33            0.500000            0.500000            0.500000
# 34            0.500000            0.500000            0.500000
# 35            0.500000            0.500000            0.500000
#
#     split33_test_score  split34_test_score  split35_test_score  \
# 0             0.809211            0.858553            0.792763
# 1             0.756579            0.848684            0.789474
# 2             0.802632            0.815789            0.809211
# 3             0.733553            0.726974            0.779605
# 4             0.726974            0.769737            0.782895
# 5             0.753289            0.733553            0.809211
# 6             0.500000            0.500000            0.500000
# 7             0.500000            0.500000            0.500000
# 8             0.500000            0.500000            0.500000
# 9             0.805921            0.822368            0.779605
# 10            0.763158            0.845395            0.799342
# 11            0.769737            0.891447            0.802632
# 12            0.723684            0.697368            0.792763
# 13            0.769737            0.750000            0.782895
# 14            0.750000            0.763158            0.763158
# 15            0.500000            0.500000            0.500000
# 16            0.500000            0.500000            0.500000
# 17            0.500000            0.500000            0.500000
# 18            0.792763            0.812500            0.802632
# 19            0.756579            0.832237            0.779605
# 20            0.776316            0.881579            0.740132
# 21            0.740132            0.733553            0.779605
# 22            0.782895            0.733553            0.766447
# 23            0.776316            0.723684            0.792763
# 24            0.500000            0.500000            0.500000
# 25            0.500000            0.500000            0.500000
# 26            0.500000            0.500000            0.500000
# 27            0.779605            0.832237            0.799342
# 28            0.769737            0.828947            0.819079
# 29            0.769737            0.832237            0.786184
# 30            0.717105            0.723684            0.832237
# 31            0.750000            0.720395            0.815789
# 32            0.743421            0.743421            0.789474
# 33            0.500000            0.500000            0.500000
# 34            0.500000            0.500000            0.500000
# 35            0.500000            0.500000            0.500000
#
#     split36_test_score  split37_test_score  split38_test_score  \
# 0             0.881579            0.750000            0.690789
# 1             0.878289            0.726974            0.720395
# 2             0.878289            0.723684            0.736842
# 3             0.809211            0.694079            0.674342
# 4             0.851974            0.713816            0.690789
# 5             0.845395            0.723684            0.651316
# 6             0.500000            0.500000            0.500000
# 7             0.500000            0.500000            0.500000
# 8             0.500000            0.500000            0.500000
# 9             0.881579            0.792763            0.740132
# 10            0.868421            0.743421            0.720395
# 11            0.875000            0.740132            0.690789
# 12            0.858553            0.661184            0.634868
# 13            0.848684            0.707237            0.707237
# 14            0.848684            0.697368            0.694079
# 15            0.500000            0.500000            0.500000
# 16            0.500000            0.500000            0.500000
# 17            0.500000            0.500000            0.500000
# 18            0.904605            0.733553            0.710526
# 19            0.861842            0.713816            0.707237
# 20            0.881579            0.766447            0.733553
# 21            0.835526            0.677632            0.690789
# 22            0.835526            0.710526            0.680921
# 23            0.875000            0.707237            0.694079
# 24            0.500000            0.500000            0.500000
# 25            0.500000            0.500000            0.500000
# 26            0.500000            0.500000            0.500000
# 27            0.875000            0.740132            0.697368
# 28            0.881579            0.763158            0.759868
# 29            0.884868            0.730263            0.720395
# 30            0.842105            0.740132            0.690789
# 31            0.838816            0.726974            0.674342
# 32            0.825658            0.680921            0.726974
# 33            0.500000            0.500000            0.500000
# 34            0.500000            0.500000            0.500000
# 35            0.500000            0.500000            0.500000
#
#     split39_test_score  split40_test_score  split41_test_score  \
# 0             0.745098            0.721362            0.829721
# 1             0.794118            0.715170            0.820433
# 2             0.758170            0.721362            0.839009
# 3             0.764706            0.622291            0.826625
# 4             0.794118            0.650155            0.860681
# 5             0.810458            0.625387            0.845201
# 6             0.500000            0.500000            0.500000
# 7             0.500000            0.500000            0.500000
# 8             0.500000            0.500000            0.500000
# 9             0.777778            0.718266            0.842105
# 10            0.758170            0.715170            0.826625
# 11            0.784314            0.696594            0.842105
# 12            0.767974            0.637771            0.826625
# 13            0.754902            0.665635            0.817337
# 14            0.748366            0.628483            0.817337
# 15            0.500000            0.500000            0.500000
# 16            0.500000            0.500000            0.500000
# 17            0.500000            0.500000            0.500000
# 18            0.758170            0.708978            0.817337
# 19            0.784314            0.724458            0.851393
# 20            0.774510            0.690402            0.839009
# 21            0.781046            0.625387            0.842105
# 22            0.787582            0.585139            0.820433
# 23            0.764706            0.640867            0.854489
# 24            0.500000            0.500000            0.500000
# 25            0.500000            0.500000            0.500000
# 26            0.500000            0.500000            0.500000
# 27            0.777778            0.730650            0.835913
# 28            0.794118            0.662539            0.848297
# 29            0.787582            0.727554            0.857585
# 30            0.748366            0.619195            0.842105
# 31            0.794118            0.674923            0.823529
# 32            0.761438            0.628483            0.823529
# 33            0.500000            0.500000            0.500000
# 34            0.500000            0.500000            0.500000
# 35            0.500000            0.500000            0.500000
#
#     split42_test_score  split43_test_score  split44_test_score  \
# 0             0.769737            0.868421            0.819079
# 1             0.789474            0.861842            0.809211
# 2             0.819079            0.861842            0.763158
# 3             0.664474            0.773026            0.825658
# 4             0.671053            0.812500            0.832237
# 5             0.746711            0.786184            0.805921
# 6             0.500000            0.500000            0.500000
# 7             0.500000            0.500000            0.500000
# 8             0.500000            0.500000            0.500000
# 9             0.805921            0.871711            0.802632
# 10            0.796053            0.805921            0.805921
# 11            0.786184            0.835526            0.819079
# 12            0.710526            0.776316            0.812500
# 13            0.730263            0.812500            0.822368
# 14            0.717105            0.792763            0.838816
# 15            0.500000            0.500000            0.500000
# 16            0.500000            0.500000            0.500000
# 17            0.500000            0.500000            0.500000
# 18            0.779605            0.851974            0.812500
# 19            0.779605            0.815789            0.812500
# 20            0.779605            0.871711            0.799342
# 21            0.677632            0.786184            0.835526
# 22            0.720395            0.779605            0.838816
# 23            0.680921            0.805921            0.825658
# 24            0.500000            0.500000            0.500000
# 25            0.500000            0.500000            0.500000
# 26            0.500000            0.500000            0.500000
# 27            0.707237            0.848684            0.805921
# 28            0.769737            0.868421            0.799342
# 29            0.796053            0.825658            0.802632
# 30            0.720395            0.776316            0.819079
# 31            0.700658            0.799342            0.832237
# 32            0.720395            0.815789            0.819079
# 33            0.500000            0.500000            0.500000
# 34            0.500000            0.500000            0.500000
# 35            0.500000            0.500000            0.500000
#
#     split45_test_score  split46_test_score  split47_test_score  \
# 0             0.802632            0.756579            0.884868
# 1             0.805921            0.726974            0.868421
# 2             0.779605            0.822368            0.884868
# 3             0.805921            0.730263            0.868421
# 4             0.809211            0.671053            0.855263
# 5             0.819079            0.717105            0.851974
# 6             0.500000            0.500000            0.500000
# 7             0.500000            0.500000            0.500000
# 8             0.500000            0.500000            0.500000
# 9             0.786184            0.786184            0.898026
# 10            0.799342            0.730263            0.881579
# 11            0.809211            0.723684            0.875000
# 12            0.815789            0.677632            0.809211
# 13            0.815789            0.664474            0.851974
# 14            0.809211            0.677632            0.825658
# 15            0.500000            0.500000            0.500000
# 16            0.500000            0.500000            0.500000
# 17            0.500000            0.500000            0.500000
# 18            0.812500            0.743421            0.894737
# 19            0.796053            0.776316            0.881579
# 20            0.769737            0.789474            0.881579
# 21            0.819079            0.664474            0.838816
# 22            0.809211            0.746711            0.848684
# 23            0.835526            0.713816            0.842105
# 24            0.500000            0.500000            0.500000
# 25            0.500000            0.500000            0.500000
# 26            0.500000            0.500000            0.500000
# 27            0.786184            0.743421            0.875000
# 28            0.769737            0.736842            0.875000
# 29            0.805921            0.723684            0.904605
# 30            0.802632            0.687500            0.835526
# ...
# 22             0.814464             0.813645             0.832013
# 23             0.815028             0.827411             0.834934
# 24             0.500000             0.500000             0.500000
# 25             0.500000             0.500000             0.500000
# 26             0.500000             0.500000             0.500000
# 27             0.870749             0.878631             0.871148
# 28             0.860234             0.872629             0.869788
# 29             0.864625             0.864186             0.859704
# 30             0.809347             0.823529             0.833533
# 31             0.816761             0.820528             0.827811
# 32             0.825907             0.825530             0.833573
# 33             0.500000             0.500000             0.500000
# 34             0.500000             0.500000             0.500000
# 35             0.500000             0.500000             0.500000
#
#     split84_train_score  split85_train_score  split86_train_score  \
# 0              0.871429             0.855302             0.861064
# 1              0.875710             0.857183             0.861585
# 2              0.860304             0.850100             0.852101
# 3              0.820368             0.818407             0.809764
# 4              0.818607             0.809364             0.804442
# 5              0.810404             0.819168             0.815046
# 6              0.500000             0.500000             0.500000
# 7              0.500000             0.500000             0.500000
# 8              0.500000             0.500000             0.500000
# 9              0.866106             0.866667             0.867467
# 10             0.872789             0.865386             0.858904
# 11             0.869548             0.849260             0.853181
# 12             0.808443             0.820848             0.806042
# 13             0.805242             0.815286             0.803601
# 14             0.797479             0.809284             0.807083
# 15             0.500000             0.500000             0.500000
# 16             0.500000             0.500000             0.500000
# 17             0.500000             0.500000             0.500000
# 18             0.863385             0.870868             0.868948
# 19             0.869148             0.849940             0.853822
# 20             0.852861             0.842457             0.848499
# 21             0.809404             0.813445             0.795358
# 22             0.802681             0.797119             0.818407
# 23             0.816246             0.816607             0.817407
# 24             0.500000             0.500000             0.500000
# 25             0.500000             0.500000             0.500000
# 26             0.500000             0.500000             0.500000
# 27             0.872749             0.867707             0.857503
# 28             0.869828             0.869868             0.864986
# 29             0.869148             0.845098             0.850500
# 30             0.815286             0.816967             0.805322
# 31             0.811965             0.802601             0.817407
# 32             0.805362             0.798239             0.810924
# 33             0.500000             0.500000             0.500000
# 34             0.500000             0.500000             0.500000
# 35             0.500000             0.500000             0.500000
#
#     split87_train_score  split88_train_score  split89_train_score  \
# 0              0.874750             0.849420             0.865657
# 1              0.880472             0.858984             0.865377
# 2              0.873109             0.849100             0.859489
# 3              0.829892             0.809124             0.808339
# 4              0.818407             0.804922             0.815950
# 5              0.828932             0.807523             0.805175
# 6              0.500000             0.500000             0.500000
# 7              0.500000             0.500000             0.500000
# 8              0.500000             0.500000             0.500000
# 9              0.878311             0.862865             0.877073
# 10             0.884314             0.858343             0.866899
# 11             0.870548             0.847739             0.860931
# 12             0.825490             0.812925             0.809701
# 13             0.828531             0.809924             0.800128
# 14             0.833173             0.806803             0.807698
# 15             0.500000             0.500000             0.500000
# 16             0.500000             0.500000             0.500000
# 17             0.500000             0.500000             0.500000
# 18             0.878391             0.847579             0.871826
# 19             0.877151             0.858784             0.865217
# 20             0.868707             0.841617             0.850837
# 21             0.827771             0.803922             0.812986
# 22             0.823129             0.793637             0.800449
# 23             0.834254             0.801841             0.817872
# 24             0.500000             0.500000             0.500000
# 25             0.500000             0.500000             0.500000
# 26             0.500000             0.500000             0.500000
# 27             0.883794             0.856463             0.869422
# 28             0.882433             0.867507             0.867259
# 29             0.876030             0.852621             0.862293
# 30             0.824610             0.820168             0.811183
# 31             0.827251             0.808003             0.806016
# 32             0.832933             0.805762             0.814668
# 33             0.500000             0.500000             0.500000
# 34             0.500000             0.500000             0.500000
# 35             0.500000             0.500000             0.500000
#
#     split90_train_score  split91_train_score  split92_train_score  \
# 0              0.868815             0.852095             0.868868
# 1              0.869944             0.857897             0.870268
# 2              0.859106             0.861966             0.860824
# 3              0.815592             0.796938             0.809284
# 4              0.826390             0.800645             0.822289
# 5              0.818856             0.808300             0.816126
# 6              0.500000             0.500000             0.500000
# 7              0.500000             0.500000             0.500000
# 8              0.500000             0.500000             0.500000
# 9              0.865068             0.856527             0.873229
# 10             0.866600             0.862208             0.865746
# 11             0.861039             0.849799             0.860744
# 12             0.818372             0.804150             0.815126
# 13             0.828122             0.813900             0.802481
# 14             0.823046             0.805882             0.822329
# 15             0.500000             0.500000             0.500000
# 16             0.500000             0.500000             0.500000
# 17             0.500000             0.500000             0.500000
# 18             0.878284             0.867768             0.863906
# 19             0.869138             0.863497             0.865346
# 20             0.864625             0.841338             0.854022
# 21             0.824899             0.806688             0.824050
# 22             0.819581             0.806527             0.808683
# 23             0.806446             0.807212             0.821809
# 24             0.500000             0.500000             0.500000
# 25             0.500000             0.500000             0.500000
# 26             0.500000             0.500000             0.500000
# 27             0.868372             0.863981             0.863585
# 28             0.869218             0.863658             0.873669
# 29             0.861281             0.839726             0.860864
# 30             0.813981             0.804029             0.824130
# 31             0.817446             0.805802             0.815366
# 32             0.824778             0.794480             0.817767
# 33             0.500000             0.500000             0.500000
# 34             0.500000             0.500000             0.500000
# 35             0.500000             0.500000             0.500000
#
#     split93_train_score  split94_train_score  split95_train_score  \
# 0              0.872349             0.864146             0.863185
# 1              0.874190             0.868187             0.865986
# 2              0.854822             0.867267             0.861064
# 3              0.824650             0.831092             0.824450
# 4              0.818327             0.836815             0.815486
# 5              0.821208             0.821889             0.809484
# 6              0.500000             0.500000             0.500000
# 7              0.500000             0.500000             0.500000
# 8              0.500000             0.500000             0.500000
# 9              0.873429             0.878511             0.874550
# 10             0.875550             0.863986             0.866947
# 11             0.866507             0.863265             0.860024
# 12             0.826811             0.816487             0.825010
# 13             0.819328             0.827971             0.815246
# 14             0.823850             0.833173             0.815526
# 15             0.500000             0.500000             0.500000
# 16             0.500000             0.500000             0.500000
# 17             0.500000             0.500000             0.500000
# 18             0.868107             0.881593             0.868027
# 19             0.868868             0.871469             0.873429
# 20             0.869028             0.868667             0.844618
# 21             0.817287             0.831773             0.823930
# 22             0.812165             0.827891             0.824210
# 23             0.819008             0.822769             0.815806
# 24             0.500000             0.500000             0.500000
# 25             0.500000             0.500000             0.500000
# 26             0.500000             0.500000             0.500000
# 27             0.873950             0.878031             0.870468
# 28             0.875630             0.878832             0.865746
# 29             0.849100             0.868267             0.862625
# 30             0.825010             0.823169             0.808323
# 31             0.811645             0.828131             0.817927
# 32             0.819408             0.821929             0.832453
# 33             0.500000             0.500000             0.500000
# 34             0.500000             0.500000             0.500000
# 35             0.500000             0.500000             0.500000
#
#     split96_train_score  split97_train_score  split98_train_score  \
# 0              0.870868             0.861825             0.866307
# 1              0.874390             0.862945             0.861785
# 2              0.867667             0.851781             0.854302
# 3              0.832133             0.815246             0.811565
# 4              0.824250             0.807723             0.821088
# 5              0.821329             0.806683             0.805842
# 6              0.500000             0.500000             0.500000
# 7              0.500000             0.500000             0.500000
# 8              0.500000             0.500000             0.500000
# 9              0.876311             0.861305             0.864826
# 10             0.870588             0.869508             0.867547
# 11             0.868267             0.849260             0.848780
# 12             0.820128             0.793317             0.808403
# 13             0.828211             0.811925             0.812485
# 14             0.813445             0.804402             0.814366
# 15             0.500000             0.500000             0.500000
# 16             0.500000             0.500000             0.500000
# 17             0.500000             0.500000             0.500000
# 18             0.872069             0.863225             0.862625
# 19             0.864026             0.862745             0.866026
# 20             0.855862             0.842337             0.853341
# 21             0.823249             0.800760             0.818007
# 22             0.819728             0.817207             0.806723
# 23             0.821929             0.800760             0.818007
# 24             0.500000             0.500000             0.500000
# 25             0.500000             0.500000             0.500000
# 26             0.500000             0.500000             0.500000
# 27             0.869508             0.867427             0.864786
# 28             0.873709             0.861665             0.870228
# 29             0.861024             0.851461             0.856062
# 30             0.829892             0.808043             0.824290
# 31             0.816126             0.804802             0.810444
# 32             0.822249             0.804882             0.813205
# 33             0.500000             0.500000             0.500000
# 34             0.500000             0.500000             0.500000
# 35             0.500000             0.500000             0.500000
#
#     split99_train_score  mean_train_score  std_train_score
# 0              0.864135          0.866405         0.007326
# 1              0.873348          0.866201         0.006947
# 2              0.848394          0.857307         0.008245
# 3              0.796523          0.815725         0.009712
# 4              0.792438          0.815299         0.010616
# 5              0.802291          0.814875         0.009919
# 6              0.500000          0.500000         0.000000
# 7              0.500000          0.500000         0.000000
# 8              0.500000          0.500000         0.000000
# 9              0.865177          0.869218         0.006844
# 10             0.873027          0.867796         0.007019
# 11             0.849355          0.858161         0.008923
# 12             0.822358          0.815672         0.010014
# 13             0.800529          0.815576         0.010378
# 14             0.812745          0.814674         0.009691
# 15             0.500000          0.500000         0.000000
# 16             0.500000          0.500000         0.000000
# 17             0.500000          0.500000         0.000000
# 18             0.859088          0.867443         0.008017
# 19             0.862213          0.866350         0.007181
# 20             0.846832          0.857809         0.009716
# 21             0.816070          0.815470         0.009139
# 22             0.810062          0.815012         0.009814
# 23             0.808540          0.815240         0.009787
# 24             0.500000          0.500000         0.000000
# 25             0.500000          0.500000         0.000000
# 26             0.500000          0.500000         0.000000
# 27             0.879596          0.868923         0.007330
# 28             0.872266          0.868685         0.007868
# 29             0.856685          0.857954         0.008723
# 30             0.810142          0.815192         0.008963
# 31             0.807218          0.814735         0.008688
# 32             0.811383          0.816763         0.010632
# 33             0.500000          0.500000         0.000000
# 34             0.500000          0.500000         0.000000
# 35             0.500000          0.500000         0.000000

# %%
display(resultados_grid.iloc[busca_grid.best_index_]['params'])
# Out:
# {'criterion': 'gini',
#  'max_depth': 3,
#  'min_samples_leaf': 32,
#  'min_samples_split': 128}

# %% [markdown]
# O modelo conseguiu atingir uma acurácia de 80,3% para os dados de teste e de 85,7% para os dados de treino.
#
# Mas esse modelo tem problemas de processamento pois ele testou as 36 combinações possíveis para os parâmetros que passamos e isso levou mais de 10 minutos.
#
# E agora vamos testar o ***RandomizedSearchCV***. Como podemos determinar a quantidade de iterações que teremos, a resposta do modelo tende a ser mais rápida. Vamos aproveitar para colocar mais parâmetros a serem testados.

# %%
from sklearn.model_selection import RandomizedSearchCV

def roda_modelo_RandomizedSearchCV(modelo, dados, n_splits, n_repeats, espaco_de_parametros, n_iter):

    np.random.seed(1231234)
    dados = dados.sample(frac=1).reset_index(drop=True)
    x_columns = dados.columns
    y = dados['ICU']
    x = dados[x_columns].drop(['ICU','WINDOW'], axis=1)


    cv = RepeatedStratifiedKFold(n_splits = n_splits, n_repeats=n_repeats)

    busca = RandomizedSearchCV(modelo, param_distributions=espaco_de_parametros,
                                n_iter = n_iter, cv = cv, scoring='roc_auc',
                                return_train_score=True)
    busca.fit(x, y)

    resultados = pd.DataFrame(busca.cv_results_)

    auc_medio = resultados.iloc[busca.best_index_]['mean_test_score']
    auc_medio_treino = resultados.iloc[busca.best_index_]['mean_train_score']

    auc_std = resultados.iloc[busca.best_index_]['std_test_score']

    print(f'AUC  {auc_medio} - {auc_medio_treino}')
    return auc_medio, auc_medio_treino, resultados, busca

# %%
from scipy.stats import randint

espaco_de_parametros_rnd = {
    'n_estimators' :randint(10, 101),
    'max_depth' : randint(3, 6),
    'min_samples_split' : randint(32, 129),
    'min_samples_leaf' : randint(32, 129),
    'bootstrap' : [True, False],
    'criterion' : ['gini', 'entropy']
}

# %%
auc_medio_rnd, auc_medio_treino_rnd, resultados_rnd, busca_rnd = roda_modelo_RandomizedSearchCV(mod_RFC, dados_limpos_sem_corr, 10, 10, espaco_de_parametros_rnd, 5)
# Out:
# AUC  0.7911730306157553 - 0.8834846805821585

# %%
resultados_rnd

# %%
#pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
#pd.set_option('display.width', None)
#pd.set_option('display.max_colwidth', None)
display(resultados_rnd.iloc[busca.best_index_]['params'])
# Out:
# {'bootstrap': False,
#  'criterion': 'entropy',
#  'max_depth': 5,
#  'min_samples_leaf': 35,
#  'min_samples_split': 47,
#  'n_estimators': 31}

# %% [markdown]
# Atingimos uma acurácia de 79,1% para os dados de teste e 88,3% para os dados de treino. Em compensação, o teste levou menos de 1 minuto para ser executado.
#
# Dependendo do tamanho da base de dados e da quantidade de parâmetros que queremos testar, esse é um *trade off* importante.

# %% [markdown]
# ### **Para saber mais: *Pipelines***
# ---

# %% [markdown]
# Pelo que eu entendi, ***pipelines*** são formas de automatizar sequências de comandos de transformação para garantir a execução sempre da mesma maneira e usando os mesmos parâmetros, o que garante a comparação entre os resultados.

# %%
from sklearn.pipeline import Pipeline
from sklearn.base import BaseEstimator, TransformerMixin

# %%
class RemoveCorrVar(BaseEstimator, TransformerMixin):
    def __init__( self, valor_corte = 0.95):
        self.valor_corte = valor_corte
        
    def fit( self, X, y = None ):
        matrix_corr = X.iloc[:,4:].corr().abs()
        matrix_upper = matrix_corr.where(np.triu(np.ones(matrix_corr.shape), k=1).astype(np.bool))
        self.excluir = [coluna for coluna in matrix_upper.columns if any(matrix_upper[coluna] > self.valor_corte)]
        return self 
    
    def transform(self, X, y = None):
        X = X.drop(self.excluir, axis=1)
        return X

# %%
def roda_modelo_cv_pipeline(modelo, dados, n_splits, n_repeats):

    np.random.seed(1231234)
    dados = dados.sample(frac=1).reset_index(drop=True)
    x_columns = dados.columns
    y = dados["ICU"]
    x = dados[x_columns].drop(["ICU","WINDOW"], axis=1)

    pipeline = Pipeline([('cat_selector', RemoveCorrVar()),
                         ('Modelo', modelo)])    
    
    cv = RepeatedStratifiedKFold(n_splits = n_splits, n_repeats=n_repeats)
    resultados=cross_validate(pipeline, x, y, cv=cv, scoring='roc_auc', return_train_score=True)
    
    auc_medio = np.mean(resultados['test_score'])
    auc_medio_treino = np.mean(resultados['train_score'])

    auc_std = np.std(resultados['test_score'])
    
    print(f'AUC  {auc_medio} - {auc_medio_treino}')
    return auc_medio, auc_medio_treino
    #print(f"AUC Médio {auc_medio} Intervalo {auc_medio - (2*auc_std)} - {auc_medio + (2*auc_std)}")

# %%
roda_modelo_cv_pipeline(mod_RFC, dados_limpos, 5, 10)
# Out:
# AUC  0.8022872753135911 - 1.0
# (0.8022872753135911, 1.0)

# %% [markdown]
# ### **Para saber mais: Salvando Seu Modelo**
# ---

# %% [markdown]
# É um artigo apresentando o ***`joblib`*** como forma de salvar o modelo, o que já foi feito no desafio da aula passada.

# %% [markdown]
# ### **O que aprendemos nessa aula?**
# ---
#
# >* Gerar uma matriz de correlação dos dados;
# >
# >* Avaliar a importação dos atributos no resultado final;
# >
# >* Desenvolver uma função para remover dados correlacionados.
#
# ---
